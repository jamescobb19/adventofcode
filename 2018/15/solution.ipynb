// %%
/* Not Needed
def getReachableSquares(grid : Array[Array[Char]], 
                        characters : ListBuffer[Character], 
                        character : Character) : Set[(Int, Int)] = {
    val newGrid = grid.map(_.clone)
    characters.foreach(character => {
        newGrid(character.getY)(character.getX) = character.getCharacterType})
    var c = character.getCoords
    var seenSquares = Set[(Int, Int)](c)
    var neighbouringSquares = directionsMap.values.to[Queue].map({case (x, y) => (x+c._1, y+c._2)})
        .filter(!seenSquares.contains(_))
        .filter({case (x, y) => newGrid(y)(x) == '.'})
    while (neighbouringSquares.length != 0) {
        c = neighbouringSquares.dequeue
        seenSquares += c
        neighbouringSquares ++= directionsMap.values.to[Queue].map({case (x, y) => (x+c._1, y+c._2)})
            .filter(!seenSquares.contains(_))
            .filter({case (x, y) => newGrid(y)(x) == '.'})
    }
    seenSquares -= character.getCoords
}
*/

// %%
/* Old method
val charTypes = Array('G', 'E')
def getShortestPathDistances(coords : (Int, Int)) : Map[(Int, Int) = {
    val newGrid = drawCharsOnGrid

    var distanceMap = Map[(Int, Int), Int](coords->0)
    var seenSquares = Set[(Int, Int)](coords)
    var neighbouringSquares = directionsMap.values.to[Queue].map({case (x, y) => (x+coords._1, y+coords._2)})
        .filter(!seenSquares.contains(_))
        .filter({case (x, y) => newGrid(y)(x) == '.'})
        .map(x => (x, 1))
    println("Initial neighbouringSquares: ", neighbouringSquares)
    while (neighbouringSquares.length != 0) {
        val (c, d) = neighbouringSquares.dequeue
        println("Next square: ", c)
        println("Distance: ", d)
        if (!seenSquares.contains(c)) {
            seenSquares += c 
            distanceMap += (c->d)
            neighbouringSquares ++= directionsMap.values.to[Queue].map({case (x, y) => (x+c._1, y+c._2)})
                .filter(!seenSquares.contains(_))
                .filter({case (x, y) => newGrid(y)(x) == '.'})
                .map(x => (x, d+1))
            println("New neighbouringSquares: ", neighbouringSquares)
        }
    }
    distanceMap
}
*/

// %%
/* Not any better
def recurseShortestPath(grid : Array[Array[Char]], 
                 seenSquares : Set[(Int, Int)], 
                 coords : (Int, Int),
                 distance : Int) : Map[(Int, Int), Int] = {
    val thisSquareMap = Map(coords->distance)
    val neighbouringSquares = directionsMap.values.to[Set].map({case (x, y) => (x+coords._1, y+coords._2)})
        .filter(!seenSquares.contains(_))
        .filter({case (x, y) => grid(y)(x) == '.'})
    if (neighbouringSquares.size == 0 || distance == 30) {
        return thisSquareMap
    }
    else {
        return thisSquareMap ++ neighbouringSquares.par.flatMap(x => 
                    recurseShortestPath(grid, seenSquares ++ neighbouringSquares, x, distance + 1)).toMap
    }
}
*/

// %%
/* Old
val character = characters(0)
val targetCharacters = characters.filter(c => c.getCharacterType != character.getCharacterType)
val neighbouringTargets = targetCharacters
      .filter(c => distance(character.getCoords, c.getCoords) == 1)
      .sorted
// Nearest character
targetCharacters.groupBy(c => distance(character.getCoords, c.getCoords)).toSeq.sortBy(_._1).head._2.sorted.head
val reachableSquares = getShortestPathDistances(grid, characters, character.getCoords)
val reachableTargetNeighbours = reachableSquares.keySet.intersect(
    targetCharacters.flatMap(c => directionsMap.values.to[Set].map({case (x, y) => (x+c.getX, y+c.getY)})).toSet)
val chosenSquare = reachableSquares.filter(x => reachableTargetNeighbours.contains(x._1)).toSeq.sortBy({case ((x,y),d) => (d, y, x)}).head._1
val neighbours = reachableSquares.filter(x => x._2 == 1)
val squareToMoveTo = getShortestPathDistances(grid, characters, chosenSquare).filter(x => neighbours.contains(x._1)).toSeq.sortBy({case ((x,y),d) => (d, y, x)}).head._1
*/

// %%
import scala.collection.mutable.ListBuffer
import scala.collection.mutable.Queue
import scala.collection.mutable.Set
val charTypes = Array('G', 'E')
val directions = Set((-1,0), (0,1), (1,0), (0,-1))
// Out:
// import scala.collection.mutable.ListBuffer
// import scala.collection.mutable.Queue
// import scala.collection.mutable.Set
// charTypes: Array[Char] = Array('G', 'E')
// directions: collection.mutable.Set[(Int, Int)] = Set(
//   (1, 0),
//   (0, 1),
//   (0, -1),
//   (-1, 0)
// )

// %%
// Create a class for the characters
class Character extends Ordered[Character] {
    // These are backwards in tuples because of 2D Array indexing/reading
    private var posX = 0
    private var posY = 0
    private var hitPoints = 200
    private var attackPower = 3
    private var characterType = ' '
    private var alive = true
    
    def this(posX: Int, posY: Int, characterType: Char) = {
        this();
        this.posX = posX;
        this.posY = posY;
        this.characterType = characterType;
    }
    def this(posX: Int, posY: Int, characterType: Char, attackPower: Int) = {
        this();
        this.posX = posX;
        this.posY = posY;
        this.characterType = characterType;
        this.attackPower = attackPower;
    }
    
    // Update the current position
    def move(coord : (Int, Int)) : Unit = {
        posX = coord._1
        posY = coord._2
    }
    
    // Reduce the hitpoints
    def takeDamage(attackPower: Int) : Unit = {
        hitPoints -= attackPower
        if (hitPoints <= 0) {
            alive = false
        }
    }
    
    override def toString(): String = {
        s"$characterType - Remaining health: $hitPoints . Currently at ($posX, $posY)"
    }
    
    // Comparison for ordering the characters
    override def compare(that: Character): Int = {
        if (posY == that.getY) 
             posX - that.getX else
             posY - that.getY
    }
    
    def getX() : Int = {posX}
    def getY() : Int = {posY}
    def getCoords() : (Int, Int) = {(posX, posY)}
    def getAttackPower() : Int = {attackPower}
    def incrementAttackPower() : Unit = {attackPower += 1}
    def getHitPoints() : Int = {hitPoints}
    def getCharacterType() : Char = {characterType}
    def isAlive() : Boolean = {alive}
    
    def copy() : Character = {new Character(posX, posY, characterType, attackPower)}
}
// Out:
// defined class Character

// %%
import scala.math.abs
def distance(c1: (Int, Int), c2: (Int, Int)) : Int = {
    abs(c1._1 - c2._1) + abs(c1._2 - c2._2)
}
// Out:
// import scala.math.abs
// defined function distance

// %%
/* Setup */
// Read in the grid
import scala.io.Source

val filename = "input"
val grid = Source.fromFile(filename).getLines.toArray.map(_ toCharArray)
var rounds = 0

// Store the characters in a structure and initialise their positions/HP
// Remap the grid to remove the characters and replace them with spaces
val inputCharacters = ListBuffer[Character]()
for {
    y <- 0 until grid.length
    x <- 0 until grid(0).length } {
    val gridChar = grid(y)(x)
    if (charTypes contains gridChar) {
        inputCharacters += new Character(x, y, gridChar)
        grid(y)(x) = '.'
    }
}
var characters = inputCharacters.map(_.copy)

// Returns a grid with the characters' positions filled in
def drawCharsOnGrid() : Array[Array[Char]] = {
    val newGrid = grid.map(_.clone)
    characters.foreach(character => {
        newGrid(character.getY)(character.getX) = character.getCharacterType})
    newGrid
}

def printGrid() : Unit = {
    val newGrid = drawCharsOnGrid
    for (row <- newGrid) {
        for (rowChar <- row) {
            print(rowChar)
        }
        println()
    }
}

// Returns a set of the neighbouring squares that are not occupied/walls
def neighbours(coords : (Int, Int)) : Set[(Int, Int)] = {
    val newGrid = drawCharsOnGrid
    directions.map({case (x, y) => (x+coords._1, y+coords._2)})
        .filter({case (x, y) => newGrid(y)(x) == '.'})
}
// Out:
// import scala.io.Source
// filename: String = "input"
// grid: Array[Array[Char]] = Array(
//   Array(
//     '#',
//     '#',
//     '#',
//     '#',
//     '#',
//     '#',
//     '#',
//     '#',
//     '#',
//     '#',
//     '#',
//     '#',
//     '#',
// ...
// rounds: Int = 0
// inputCharacters: ListBuffer[Character] = ListBuffer(
//   G - Remaining health: 200 . Currently at (10, 2),
//   G - Remaining health: 200 . Currently at (14, 3),
//   G - Remaining health: 200 . Currently at (15, 6),
//   G - Remaining health: 200 . Currently at (17, 8),
//   G - Remaining health: 200 . Currently at (17, 9),
//   G - Remaining health: 200 . Currently at (4, 10),
//   G - Remaining health: 200 . Currently at (5, 10),
//   G - Remaining health: 200 . Currently at (2, 11),
//   G - Remaining health: 200 . Currently at (4, 12),
//   G - Remaining health: 200 . Currently at (6, 12),
//   G - Remaining health: 200 . Currently at (12, 12),
//   E - Remaining health: 200 . Currently at (22, 12),
//   G - Remaining health: 200 . Currently at (26, 12),
//   G - Remaining health: 200 . Currently at (2, 14),
// ...
// characters: ListBuffer[Character] = ListBuffer(
//   G - Remaining health: 200 . Currently at (10, 2),
//   G - Remaining health: 200 . Currently at (14, 3),
//   G - Remaining health: 200 . Currently at (15, 6),
//   G - Remaining health: 200 . Currently at (17, 8),
//   G - Remaining health: 200 . Currently at (17, 9),
//   G - Remaining health: 200 . Currently at (4, 10),
//   G - Remaining health: 200 . Currently at (5, 10),
//   G - Remaining health: 200 . Currently at (2, 11),
//   G - Remaining health: 200 . Currently at (4, 12),
//   G - Remaining health: 200 . Currently at (6, 12),
//   G - Remaining health: 200 . Currently at (12, 12),
//   E - Remaining health: 200 . Currently at (22, 12),
//   G - Remaining health: 200 . Currently at (26, 12),
//   G - Remaining health: 200 . Currently at (2, 14),
// ...
// defined function drawCharsOnGrid
// defined function printGrid
// defined function neighbours

// %%
def moveTowardsNearestTarget(character : Character,
                 targetCoords : ListBuffer[(Int, Int)]) : Unit = {
    val newGrid = drawCharsOnGrid
    
    var targetDistance = -1
    val targetNeighbours = targetCoords.flatMap(neighbours)
    val potentialChosenSquares = ListBuffer[(Int, Int)]()
    var currentCoord = character.getCoords
    var currentDistance = 1
    var distanceMap = Map[(Int, Int), Int](currentCoord->0)
    var coordNeighbours = neighbours(currentCoord) 
    var squaresToCheck = coordNeighbours.to[Queue]
    distanceMap ++= coordNeighbours.map(neighbour => (neighbour, currentDistance))
    
    // BFS - Move out to each of the neighbours.
    // Iteratively do this until on of the target squares is hit.
    // At this point, keep going until the distance becomes the target distance +1
    while (squaresToCheck.length != 0 && currentDistance != targetDistance + 1) {
        currentCoord = squaresToCheck.dequeue
        currentDistance = distanceMap(currentCoord)
        if (currentDistance != targetDistance + 1) {
            if (targetNeighbours.contains(currentCoord)) {
                targetDistance = currentDistance
                potentialChosenSquares += currentCoord
            }
            else {
                coordNeighbours = neighbours(currentCoord)
                    .filter(neighbour => !distanceMap.keySet.contains(neighbour))
                squaresToCheck ++= coordNeighbours
                distanceMap ++= coordNeighbours.map(neighbour => (neighbour, currentDistance+1))
            }
        }
    }
    
    // Choose a square based on reading order (if one was found).
    if (targetDistance != -1) {
        val chosenSquare = potentialChosenSquares.sortBy({case (x,y) => (y, x)}).head
        currentDistance = targetDistance
        var nextSteps = Set[(Int, Int)](chosenSquare)
        // Propagate back to the original square following the neighbours in the map that have d-1 iteratively.
        while(currentDistance != 1) {
            nextSteps = nextSteps.flatMap(neighbours _)
                .filter(neighbour => distanceMap.contains(neighbour) && distanceMap(neighbour) == currentDistance-1)
            currentDistance -= 1
        }
        character.move(nextSteps.toSeq.sortBy({case (x,y) => (y, x)}).head)
    }
}
// Out:
// defined function moveTowardsNearestTarget

// %%
//println("Rounds: ", rounds)
//characters.foreach(println)
//printGrid
while (characters.filter(c => c.getCharacterType == 'G').length > 0 &&
       characters.filter(c => c.getCharacterType == 'E').length > 0) {
    var fullRoundCompleted = true
    val charactersToMove = characters.sorted
    charactersToMove.foreach(character => {
        if (character.isAlive) {
            val targetCharacters = characters.filter(c => c.getCharacterType != character.getCharacterType)
            if (targetCharacters.length == 0) {
                fullRoundCompleted = false
            }
            // Check if there are any neighbouring targets
            var neighbouringTargets = targetCharacters
              .filter(c => distance(character.getCoords, c.getCoords) == 1)
              .sortBy(c => (c.getHitPoints, c.getY, c.getX))
            if (neighbouringTargets.length == 0) {
                // Move towards the nearest reachable square
                moveTowardsNearestTarget(character, targetCharacters.map(_ getCoords))
                neighbouringTargets = targetCharacters
                  .filter(c => distance(character.getCoords, c.getCoords) == 1)
                  .sortBy(c => (c.getHitPoints, c.getY, c.getX))
            }
            // Redetermine whether we should attack
            if (neighbouringTargets.length >= 1) {
                // Attack the first target in neighbouring targets
                val target = neighbouringTargets.head
                target.takeDamage(character.getAttackPower)
                if (!target.isAlive) {  
                    characters -= target
                }
            }
        }
    })
    if (fullRoundCompleted) {
      rounds += 1
    }
    println("\rRounds: " + rounds + ", numChars: " + characters.length)
    //printGrid
    //characters.foreach(println)
}
//rounds * characters.map(_ getHitPoints).sum
// Out:
// Rounds: 1, numChars: 30
// Rounds: 2, numChars: 30
// Rounds: 3, numChars: 30
// Rounds: 4, numChars: 30
// Rounds: 5, numChars: 30
// Rounds: 6, numChars: 30
// Rounds: 7, numChars: 30
// Rounds: 8, numChars: 30
// Rounds: 9, numChars: 30
// Rounds: 10, numChars: 30
// Rounds: 11, numChars: 30
// Rounds: 12, numChars: 30
// Rounds: 13, numChars: 30
// Rounds: 14, numChars: 30
// Rounds: 15, numChars: 30
// Rounds: 16, numChars: 30
// Rounds: 17, numChars: 30
// Rounds: 18, numChars: 30
// Rounds: 19, numChars: 30
// Rounds: 20, numChars: 30
// Rounds: 21, numChars: 30
// Rounds: 22, numChars: 30
// Rounds: 23, numChars: 30
// Rounds: 24, numChars: 30
// Rounds: 25, numChars: 30
// Rounds: 26, numChars: 30
// Rounds: 27, numChars: 29
// Rounds: 28, numChars: 29
// Rounds: 29, numChars: 28
// Rounds: 30, numChars: 28
// Rounds: 31, numChars: 28
// Rounds: 32, numChars: 28
// Rounds: 33, numChars: 28
// Rounds: 34, numChars: 28
// Rounds: 35, numChars: 28
// Rounds: 36, numChars: 28
// Rounds: 37, numChars: 28
// Rounds: 38, numChars: 28
// Rounds: 39, numChars: 27
// Rounds: 40, numChars: 27
// Rounds: 41, numChars: 27
// Rounds: 42, numChars: 27
// Rounds: 43, numChars: 27
// Rounds: 44, numChars: 27
// Rounds: 45, numChars: 27
// Rounds: 46, numChars: 27
// Rounds: 47, numChars: 26
// Rounds: 48, numChars: 26
// Rounds: 49, numChars: 26
// Rounds: 50, numChars: 25
// Rounds: 51, numChars: 25
// Rounds: 52, numChars: 24
// Rounds: 53, numChars: 24
// Rounds: 54, numChars: 23
// Rounds: 55, numChars: 23
// Rounds: 56, numChars: 23
// Rounds: 57, numChars: 23
// Rounds: 58, numChars: 23
// Rounds: 59, numChars: 23
// Rounds: 60, numChars: 23
// Rounds: 61, numChars: 23
// Rounds: 62, numChars: 23
// Rounds: 63, numChars: 23
// Rounds: 64, numChars: 22
// Rounds: 65, numChars: 22
// Rounds: 66, numChars: 21
// Rounds: 67, numChars: 21
// Rounds: 68, numChars: 21
// Rounds: 69, numChars: 21
// Rounds: 70, numChars: 20
// Rounds: 71, numChars: 20
// Rounds: 72, numChars: 20
// Rounds: 73, numChars: 19
// Rounds: 74, numChars: 18
// Rounds: 75, numChars: 18
// Rounds: 76, numChars: 18
// Rounds: 77, numChars: 18
// Rounds: 78, numChars: 18
// Rounds: 79, numChars: 18
// Rounds: 80, numChars: 18
// Rounds: 81, numChars: 18
// Rounds: 82, numChars: 18
// Rounds: 83, numChars: 18
// Rounds: 84, numChars: 18
// Rounds: 85, numChars: 18
// Rounds: 86, numChars: 17
// Rounds: 87, numChars: 17
// Rounds: 88, numChars: 17
// Rounds: 89, numChars: 17
// Rounds: 90, numChars: 17
// Rounds: 91, numChars: 16
// Rounds: 92, numChars: 15
// Rounds: 93, numChars: 15
// Rounds: 94, numChars: 15
// Rounds: 95, numChars: 15
// Rounds: 96, numChars: 15
// Rounds: 97, numChars: 15
// Rounds: 98, numChars: 15
// Rounds: 99, numChars: 15
// Rounds: 100, numChars: 15
// Rounds: 101, numChars: 15
// Rounds: 102, numChars: 15
// Rounds: 103, numChars: 15
// Rounds: 104, numChars: 14
// Rounds: 105, numChars: 14
// Rounds: 106, numChars: 14
// Rounds: 107, numChars: 14
// Rounds: 107, numChars: 13

// %%
println("Rounds: ", rounds)
characters.foreach(println)
printGrid
characters.map(_ getHitPoints).sum
rounds * characters.map(_ getHitPoints).sum
// Out:
// (Rounds: ,107)
// G - Remaining health: 191 . Currently at (18, 22)
// G - Remaining health: 200 . Currently at (23, 14)
// G - Remaining health: 143 . Currently at (21, 15)
// G - Remaining health: 194 . Currently at (22, 13)
// G - Remaining health: 200 . Currently at (19, 23)
// G - Remaining health: 200 . Currently at (20, 11)
// G - Remaining health: 200 . Currently at (17, 23)
// G - Remaining health: 200 . Currently at (18, 21)
// G - Remaining health: 200 . Currently at (22, 12)
// G - Remaining health: 200 . Currently at (11, 16)
// G - Remaining health: 77 . Currently at (12, 11)
// G - Remaining health: 200 . Currently at (14, 10)
// G - Remaining health: 137 . Currently at (10, 13)
// ################################
// ##############.#################
// ##########.##....###############
// #########.......################
// #########...........############
// #########...........############
// ##########.........#############
// ###########.........############
// ########.#.#..#.......##########
// #######.................########
// ##............G.........###.####
// ##..........G.......G........###
// ####..........#####...G.#....###
// #....##...G..#######..G.....####
// #....#####..#########..G....####
// ###..####...#########G.....#####
// #...####...G#########........###
// #...###.....#########.........##
// #..####.....#########.........##
// #..###.......#######..........##
// #..##.........#####..........###
// #.................G....#.......#
// ##................G...#.......##
// ##............#..G.G.....#..####
// ###.....#...#.##..#......#######
// #####.###...#######...#..#######
// #########....######....#########
// ###########...######.###########
// ############..#####..###########
// #############....##.############
// ################.#..############
// ################################
// res11_3: Int = 2342
// res11_4: Int = 250594

// %% [markdown]
// ## Part 2

// %%
//println("Rounds: ", rounds)
//characters.foreach(println)
//printGrid
var elvesDied = true
var attackPower = 3
while (elvesDied) {
    inputCharacters.filter(c => c.getCharacterType == 'E').foreach(_ incrementAttackPower)
    characters = inputCharacters.map(_.copy)
    rounds = 0
    attackPower += 1
    while (characters.filter(c => c.getCharacterType == 'G').length > 0 &&
           characters.filter(c => c.getCharacterType == 'E').length > 0) {
        var fullRoundCompleted = true
        val charactersToMove = characters.sorted
        charactersToMove.foreach(character => {
            if (character.isAlive) {
                val targetCharacters = characters.filter(c => c.getCharacterType != character.getCharacterType)
                if (targetCharacters.length == 0) {
                    fullRoundCompleted = false
                }
                // Check if there are any neighbouring targets
                var neighbouringTargets = targetCharacters
                  .filter(c => distance(character.getCoords, c.getCoords) == 1)
                  .sortBy(c => (c.getHitPoints, c.getY, c.getX))
                if (neighbouringTargets.length == 0) {
                    // Move towards the nearest reachable square
                    moveTowardsNearestTarget(character, targetCharacters.map(_ getCoords))
                    neighbouringTargets = targetCharacters
                      .filter(c => distance(character.getCoords, c.getCoords) == 1)
                      .sortBy(c => (c.getHitPoints, c.getY, c.getX))
                }
                // Redetermine whether we should attack
                if (neighbouringTargets.length >= 1) {
                    // Attack the first target in neighbouring targets
                    val target = neighbouringTargets.head
                    target.takeDamage(character.getAttackPower)
                    if (!target.isAlive) {  
                        characters -= target
                    }
                }
            }
        })
        if (fullRoundCompleted) {
          rounds += 1
        }
        println("\rRounds: " + rounds + ", numChars: " + characters.length)
        //printGrid
        //characters.foreach(println)
    }
    elvesDied = characters.filter(c => c.getCharacterType == 'E').length < 
                inputCharacters.filter(c => c.getCharacterType == 'E').length
    println("\rAttackPower: " + attackPower)
}
rounds * characters.map(_ getHitPoints).sum
// Out:
// Rounds: 1, numChars: 30
// Rounds: 2, numChars: 30
// Rounds: 3, numChars: 30
// Rounds: 4, numChars: 30
// Rounds: 5, numChars: 30
// Rounds: 6, numChars: 30
// Rounds: 7, numChars: 30
// Rounds: 8, numChars: 30
// Rounds: 9, numChars: 30
// Rounds: 10, numChars: 30
// Rounds: 11, numChars: 30
// Rounds: 12, numChars: 30
// Rounds: 13, numChars: 30
// Rounds: 14, numChars: 30
// Rounds: 15, numChars: 30
// Rounds: 16, numChars: 30
// Rounds: 17, numChars: 30
// Rounds: 18, numChars: 30
// Rounds: 19, numChars: 30
// Rounds: 20, numChars: 30
// Rounds: 21, numChars: 29
// Rounds: 22, numChars: 29
// Rounds: 23, numChars: 29
// Rounds: 24, numChars: 29
// Rounds: 25, numChars: 29
// Rounds: 26, numChars: 29
// Rounds: 27, numChars: 29
// Rounds: 28, numChars: 29
// Rounds: 29, numChars: 28
// Rounds: 30, numChars: 27
// Rounds: 31, numChars: 27
// Rounds: 32, numChars: 27
// Rounds: 33, numChars: 27
// Rounds: 34, numChars: 27
// Rounds: 35, numChars: 27
// Rounds: 36, numChars: 27
// Rounds: 37, numChars: 27
// Rounds: 38, numChars: 27
// Rounds: 39, numChars: 27
// Rounds: 40, numChars: 26
// Rounds: 41, numChars: 26
// Rounds: 42, numChars: 26
// Rounds: 43, numChars: 26
// Rounds: 44, numChars: 26
// Rounds: 45, numChars: 26
// Rounds: 46, numChars: 26
// Rounds: 47, numChars: 25
// Rounds: 48, numChars: 24
// Rounds: 49, numChars: 24
// Rounds: 50, numChars: 24
// Rounds: 51, numChars: 24
// Rounds: 52, numChars: 23
// Rounds: 53, numChars: 22
// Rounds: 54, numChars: 21
// Rounds: 55, numChars: 21
// Rounds: 56, numChars: 21
// Rounds: 57, numChars: 21
// Rounds: 58, numChars: 21
// Rounds: 59, numChars: 20
// Rounds: 60, numChars: 20
// Rounds: 61, numChars: 19
// Rounds: 62, numChars: 19
// Rounds: 63, numChars: 19
// Rounds: 64, numChars: 19
// Rounds: 65, numChars: 19
// Rounds: 66, numChars: 19
// Rounds: 67, numChars: 19
// Rounds: 68, numChars: 19
// Rounds: 69, numChars: 19
// Rounds: 70, numChars: 19
// Rounds: 71, numChars: 19
// Rounds: 72, numChars: 19
// Rounds: 73, numChars: 19
// Rounds: 74, numChars: 19
// Rounds: 75, numChars: 19
// Rounds: 76, numChars: 19
// Rounds: 77, numChars: 19
// Rounds: 78, numChars: 19
// Rounds: 79, numChars: 18
// Rounds: 80, numChars: 18
// Rounds: 81, numChars: 17
// Rounds: 82, numChars: 17
// Rounds: 83, numChars: 17
// Rounds: 84, numChars: 16
// Rounds: 85, numChars: 16
// Rounds: 86, numChars: 16
// Rounds: 87, numChars: 16
// Rounds: 88, numChars: 15
// Rounds: 89, numChars: 14
// Rounds: 90, numChars: 14
// Rounds: 91, numChars: 14
// Rounds: 92, numChars: 14
// Rounds: 93, numChars: 14
// Rounds: 94, numChars: 14
// Rounds: 95, numChars: 14
// Rounds: 96, numChars: 14
// Rounds: 97, numChars: 14
// Rounds: 98, numChars: 14
// Rounds: 99, numChars: 13
// Rounds: 100, numChars: 13
// Rounds: 101, numChars: 13
// Rounds: 102, numChars: 13
// Rounds: 103, numChars: 13
// Rounds: 103, numChars: 12
// AttackPower: 4
// Rounds: 1, numChars: 30
// Rounds: 2, numChars: 30
// Rounds: 3, numChars: 30
// Rounds: 4, numChars: 30
// Rounds: 5, numChars: 30
// Rounds: 6, numChars: 30
// Rounds: 7, numChars: 30
// Rounds: 8, numChars: 30
// Rounds: 9, numChars: 30
// Rounds: 10, numChars: 30
// Rounds: 11, numChars: 30
// Rounds: 12, numChars: 30
// Rounds: 13, numChars: 30
// Rounds: 14, numChars: 30
// Rounds: 15, numChars: 30
// Rounds: 16, numChars: 30
// Rounds: 17, numChars: 30
// Rounds: 18, numChars: 29
// Rounds: 19, numChars: 29
// Rounds: 20, numChars: 29
// Rounds: 21, numChars: 29
// Rounds: 22, numChars: 29
// Rounds: 23, numChars: 29
// Rounds: 24, numChars: 29
// Rounds: 25, numChars: 28
// Rounds: 26, numChars: 28
// Rounds: 27, numChars: 28
// Rounds: 28, numChars: 28
// Rounds: 29, numChars: 27
// Rounds: 30, numChars: 27
// Rounds: 31, numChars: 27
// Rounds: 32, numChars: 27
// Rounds: 33, numChars: 27
// Rounds: 34, numChars: 26
// Rounds: 35, numChars: 26
// Rounds: 36, numChars: 26
// Rounds: 37, numChars: 26
// Rounds: 38, numChars: 26
// Rounds: 39, numChars: 26
// Rounds: 40, numChars: 25
// Rounds: 41, numChars: 25
// Rounds: 42, numChars: 25
// Rounds: 43, numChars: 25
// Rounds: 44, numChars: 24
// Rounds: 45, numChars: 23
// Rounds: 46, numChars: 22
// Rounds: 47, numChars: 22
// Rounds: 48, numChars: 21
// Rounds: 49, numChars: 21
// Rounds: 50, numChars: 21
// Rounds: 51, numChars: 21
// Rounds: 52, numChars: 20
// Rounds: 53, numChars: 20
// Rounds: 54, numChars: 19
// Rounds: 55, numChars: 19
// Rounds: 56, numChars: 19
// Rounds: 57, numChars: 19
// Rounds: 58, numChars: 19
// Rounds: 59, numChars: 19
// Rounds: 60, numChars: 18
// Rounds: 61, numChars: 18
// Rounds: 62, numChars: 18
// Rounds: 63, numChars: 17
// Rounds: 64, numChars: 17
// Rounds: 65, numChars: 16
// Rounds: 66, numChars: 16
// Rounds: 67, numChars: 15
// Rounds: 68, numChars: 15
// Rounds: 69, numChars: 15
// Rounds: 70, numChars: 14
// Rounds: 71, numChars: 14
// Rounds: 72, numChars: 14
// Rounds: 73, numChars: 14
// Rounds: 74, numChars: 13
// Rounds: 75, numChars: 13
// Rounds: 76, numChars: 13
// Rounds: 77, numChars: 13
// Rounds: 78, numChars: 13
// Rounds: 79, numChars: 13
// Rounds: 80, numChars: 12
// Rounds: 81, numChars: 12
// Rounds: 82, numChars: 12
// Rounds: 83, numChars: 12
// Rounds: 84, numChars: 12
// Rounds: 85, numChars: 12
// Rounds: 86, numChars: 12
// Rounds: 87, numChars: 11
// Rounds: 88, numChars: 11
// Rounds: 89, numChars: 11
// Rounds: 90, numChars: 11
// Rounds: 91, numChars: 11
// Rounds: 92, numChars: 11
// Rounds: 93, numChars: 11
// Rounds: 94, numChars: 11
// Rounds: 95, numChars: 9
// Rounds: 96, numChars: 9
// Rounds: 97, numChars: 9
// Rounds: 98, numChars: 9
// Rounds: 99, numChars: 9
// Rounds: 100, numChars: 9
// Rounds: 101, numChars: 9
// Rounds: 102, numChars: 9
// Rounds: 103, numChars: 9
// Rounds: 103, numChars: 8
// AttackPower: 5
// Rounds: 1, numChars: 30
// Rounds: 2, numChars: 30
// Rounds: 3, numChars: 30
// Rounds: 4, numChars: 30
// Rounds: 5, numChars: 30
// Rounds: 6, numChars: 30
// Rounds: 7, numChars: 30
// Rounds: 8, numChars: 30
// Rounds: 9, numChars: 30
// Rounds: 10, numChars: 30
// Rounds: 11, numChars: 30
// Rounds: 12, numChars: 30
// Rounds: 13, numChars: 30
// Rounds: 14, numChars: 30
// Rounds: 15, numChars: 30
// Rounds: 16, numChars: 29
// Rounds: 17, numChars: 29
// Rounds: 18, numChars: 29
// Rounds: 19, numChars: 29
// Rounds: 20, numChars: 29
// Rounds: 21, numChars: 29
// Rounds: 22, numChars: 28
// Rounds: 23, numChars: 28
// Rounds: 24, numChars: 28
// Rounds: 25, numChars: 28
// Rounds: 26, numChars: 28
// Rounds: 27, numChars: 28
// Rounds: 28, numChars: 28
// Rounds: 29, numChars: 27
// Rounds: 30, numChars: 26
// Rounds: 31, numChars: 26
// Rounds: 32, numChars: 26
// Rounds: 33, numChars: 26
// Rounds: 34, numChars: 26
// Rounds: 35, numChars: 25
// Rounds: 36, numChars: 25
// Rounds: 37, numChars: 25
// Rounds: 38, numChars: 25
// Rounds: 39, numChars: 23
// Rounds: 40, numChars: 22
// Rounds: 41, numChars: 22
// Rounds: 42, numChars: 22
// Rounds: 43, numChars: 22
// Rounds: 44, numChars: 22
// Rounds: 45, numChars: 22
// Rounds: 46, numChars: 22
// Rounds: 47, numChars: 22
// Rounds: 48, numChars: 22
// Rounds: 49, numChars: 22
// Rounds: 50, numChars: 21
// Rounds: 51, numChars: 20
// Rounds: 52, numChars: 20
// Rounds: 53, numChars: 19
// Rounds: 54, numChars: 19
// Rounds: 55, numChars: 18
// Rounds: 56, numChars: 17
// Rounds: 57, numChars: 17
// Rounds: 58, numChars: 17
// Rounds: 59, numChars: 17
// Rounds: 60, numChars: 17
// Rounds: 61, numChars: 17
// Rounds: 62, numChars: 17
// Rounds: 63, numChars: 16
// Rounds: 64, numChars: 16
// Rounds: 65, numChars: 16
// Rounds: 66, numChars: 16
// Rounds: 67, numChars: 16
// Rounds: 68, numChars: 15
// Rounds: 69, numChars: 15
// Rounds: 70, numChars: 15
// Rounds: 71, numChars: 14
// Rounds: 72, numChars: 14
// Rounds: 73, numChars: 14
// Rounds: 74, numChars: 14
// Rounds: 75, numChars: 13
// Rounds: 76, numChars: 13
// Rounds: 77, numChars: 12
// Rounds: 78, numChars: 11
// Rounds: 79, numChars: 11
// Rounds: 80, numChars: 11
// Rounds: 81, numChars: 11
// Rounds: 82, numChars: 11
// Rounds: 83, numChars: 10
// Rounds: 84, numChars: 10
// Rounds: 85, numChars: 10
// Rounds: 86, numChars: 10
// Rounds: 87, numChars: 10
// Rounds: 88, numChars: 9
// Rounds: 89, numChars: 8
// Rounds: 90, numChars: 8
// Rounds: 91, numChars: 8
// Rounds: 92, numChars: 8
// Rounds: 93, numChars: 8
// Rounds: 94, numChars: 8
// Rounds: 95, numChars: 8
// Rounds: 96, numChars: 8
// Rounds: 97, numChars: 8
// Rounds: 98, numChars: 8
// Rounds: 99, numChars: 8
// Rounds: 100, numChars: 8
// Rounds: 101, numChars: 8
// Rounds: 102, numChars: 7
// Rounds: 103, numChars: 6
// Rounds: 104, numChars: 6
// Rounds: 105, numChars: 6
// Rounds: 106, numChars: 6
// Rounds: 107, numChars: 6
// Rounds: 108, numChars: 6
// Rounds: 109, numChars: 6
// Rounds: 110, numChars: 6
// Rounds: 111, numChars: 5
// Rounds: 112, numChars: 5
// Rounds: 113, numChars: 5
// Rounds: 114, numChars: 5
// Rounds: 115, numChars: 5
// Rounds: 116, numChars: 5
// Rounds: 117, numChars: 4
// Rounds: 118, numChars: 4
// Rounds: 119, numChars: 4
// Rounds: 120, numChars: 4
// Rounds: 121, numChars: 4
// Rounds: 122, numChars: 4
// Rounds: 123, numChars: 4
// Rounds: 124, numChars: 4
// Rounds: 125, numChars: 3
// AttackPower: 6
// Rounds: 1, numChars: 30
// Rounds: 2, numChars: 30
// Rounds: 3, numChars: 30
// Rounds: 4, numChars: 30
// Rounds: 5, numChars: 30
// Rounds: 6, numChars: 30
// Rounds: 7, numChars: 30
// Rounds: 8, numChars: 30
// Rounds: 9, numChars: 30
// Rounds: 10, numChars: 30
// Rounds: 11, numChars: 30
// Rounds: 12, numChars: 30
// Rounds: 13, numChars: 30
// Rounds: 14, numChars: 29
// Rounds: 15, numChars: 29
// Rounds: 16, numChars: 29
// Rounds: 17, numChars: 29
// Rounds: 18, numChars: 29
// Rounds: 19, numChars: 29
// Rounds: 20, numChars: 28
// Rounds: 21, numChars: 28
// Rounds: 22, numChars: 28
// Rounds: 23, numChars: 28
// Rounds: 24, numChars: 28
// Rounds: 25, numChars: 28
// Rounds: 26, numChars: 27
// Rounds: 27, numChars: 27
// Rounds: 28, numChars: 27
// Rounds: 29, numChars: 26
// Rounds: 30, numChars: 26
// Rounds: 31, numChars: 25
// Rounds: 32, numChars: 25
// Rounds: 33, numChars: 25
// Rounds: 34, numChars: 24
// Rounds: 35, numChars: 23
// Rounds: 36, numChars: 23
// Rounds: 37, numChars: 23
// Rounds: 38, numChars: 23
// Rounds: 39, numChars: 23
// Rounds: 40, numChars: 23
// Rounds: 41, numChars: 23
// Rounds: 42, numChars: 22
// Rounds: 43, numChars: 22
// Rounds: 44, numChars: 22
// Rounds: 45, numChars: 22
// Rounds: 46, numChars: 22
// Rounds: 47, numChars: 22
// Rounds: 48, numChars: 21
// Rounds: 49, numChars: 19
// Rounds: 50, numChars: 17
// Rounds: 51, numChars: 17
// Rounds: 52, numChars: 17
// Rounds: 53, numChars: 16
// Rounds: 54, numChars: 16
// Rounds: 55, numChars: 16
// Rounds: 56, numChars: 16
// Rounds: 57, numChars: 15
// Rounds: 58, numChars: 15
// Rounds: 59, numChars: 15
// Rounds: 60, numChars: 15
// Rounds: 61, numChars: 15
// Rounds: 62, numChars: 14
// Rounds: 63, numChars: 14
// Rounds: 64, numChars: 13
// Rounds: 65, numChars: 13
// Rounds: 66, numChars: 13
// Rounds: 67, numChars: 13
// Rounds: 68, numChars: 13
// Rounds: 69, numChars: 13
// Rounds: 70, numChars: 13
// Rounds: 71, numChars: 13
// Rounds: 72, numChars: 13
// Rounds: 73, numChars: 13
// Rounds: 74, numChars: 12
// Rounds: 75, numChars: 12
// Rounds: 76, numChars: 12
// Rounds: 77, numChars: 12
// Rounds: 78, numChars: 12
// Rounds: 79, numChars: 12
// Rounds: 80, numChars: 11
// Rounds: 81, numChars: 11
// Rounds: 82, numChars: 11
// Rounds: 83, numChars: 11
// Rounds: 84, numChars: 11
// Rounds: 85, numChars: 10
// Rounds: 86, numChars: 8
// Rounds: 87, numChars: 8
// Rounds: 88, numChars: 7
// Rounds: 89, numChars: 7
// Rounds: 90, numChars: 7
// Rounds: 91, numChars: 6
// Rounds: 92, numChars: 6
// Rounds: 93, numChars: 5
// Rounds: 94, numChars: 5
// Rounds: 95, numChars: 5
// Rounds: 96, numChars: 5
// Rounds: 97, numChars: 4
// AttackPower: 7
// Rounds: 1, numChars: 30
// Rounds: 2, numChars: 30
// Rounds: 3, numChars: 30
// Rounds: 4, numChars: 30
// Rounds: 5, numChars: 30
// Rounds: 6, numChars: 30
// Rounds: 7, numChars: 30
// Rounds: 8, numChars: 30
// Rounds: 9, numChars: 30
// Rounds: 10, numChars: 30
// Rounds: 11, numChars: 30
// Rounds: 12, numChars: 30
// Rounds: 13, numChars: 29
// Rounds: 14, numChars: 29
// Rounds: 15, numChars: 29
// Rounds: 16, numChars: 29
// Rounds: 17, numChars: 29
// Rounds: 18, numChars: 28
// Rounds: 19, numChars: 28
// Rounds: 20, numChars: 28
// Rounds: 21, numChars: 28
// Rounds: 22, numChars: 28
// Rounds: 23, numChars: 28
// Rounds: 24, numChars: 27
// Rounds: 25, numChars: 27
// Rounds: 26, numChars: 27
// Rounds: 27, numChars: 27
// Rounds: 28, numChars: 26
// Rounds: 29, numChars: 24
// Rounds: 30, numChars: 24
// Rounds: 31, numChars: 23
// Rounds: 32, numChars: 22
// Rounds: 33, numChars: 22
// Rounds: 34, numChars: 21
// Rounds: 35, numChars: 21
// Rounds: 36, numChars: 21
// Rounds: 37, numChars: 21
// Rounds: 38, numChars: 21
// Rounds: 39, numChars: 21
// Rounds: 40, numChars: 21
// Rounds: 41, numChars: 21
// Rounds: 42, numChars: 20
// Rounds: 43, numChars: 20
// Rounds: 44, numChars: 19
// Rounds: 45, numChars: 19
// Rounds: 46, numChars: 19
// Rounds: 47, numChars: 19
// Rounds: 48, numChars: 18
// Rounds: 49, numChars: 18
// Rounds: 50, numChars: 17
// Rounds: 51, numChars: 17
// Rounds: 52, numChars: 16
// Rounds: 53, numChars: 16
// Rounds: 54, numChars: 16
// Rounds: 55, numChars: 16
// Rounds: 56, numChars: 14
// Rounds: 57, numChars: 14
// Rounds: 58, numChars: 13
// Rounds: 59, numChars: 13
// Rounds: 60, numChars: 13
// Rounds: 61, numChars: 13
// Rounds: 62, numChars: 13
// Rounds: 63, numChars: 13
// Rounds: 64, numChars: 13
// Rounds: 65, numChars: 12
// Rounds: 66, numChars: 12
// Rounds: 67, numChars: 12
// Rounds: 68, numChars: 10
// Rounds: 69, numChars: 10
// Rounds: 70, numChars: 10
// Rounds: 71, numChars: 10
// Rounds: 72, numChars: 10
// Rounds: 73, numChars: 10
// Rounds: 74, numChars: 10
// Rounds: 75, numChars: 10
// Rounds: 76, numChars: 10
// Rounds: 77, numChars: 10
// Rounds: 78, numChars: 9
// Rounds: 79, numChars: 8
// Rounds: 80, numChars: 8
// Rounds: 81, numChars: 7
// Rounds: 82, numChars: 7
// Rounds: 83, numChars: 6
// Rounds: 84, numChars: 6
// Rounds: 85, numChars: 6
// Rounds: 86, numChars: 5
// Rounds: 87, numChars: 5
// Rounds: 88, numChars: 5
// Rounds: 89, numChars: 5
// Rounds: 90, numChars: 5
// Rounds: 91, numChars: 5
// Rounds: 92, numChars: 5
// Rounds: 92, numChars: 4
// AttackPower: 8
// Rounds: 1, numChars: 30
// Rounds: 2, numChars: 30
// Rounds: 3, numChars: 30
// Rounds: 4, numChars: 30
// Rounds: 5, numChars: 30
// Rounds: 6, numChars: 30
// Rounds: 7, numChars: 30
// Rounds: 8, numChars: 30
// Rounds: 9, numChars: 30
// Rounds: 10, numChars: 30
// Rounds: 11, numChars: 30
// Rounds: 12, numChars: 29
// Rounds: 13, numChars: 29
// Rounds: 14, numChars: 29
// Rounds: 15, numChars: 29
// Rounds: 16, numChars: 29
// Rounds: 17, numChars: 28
// Rounds: 18, numChars: 28
// Rounds: 19, numChars: 28
// Rounds: 20, numChars: 28
// Rounds: 21, numChars: 28
// Rounds: 22, numChars: 27
// Rounds: 23, numChars: 27
// Rounds: 24, numChars: 27
// Rounds: 25, numChars: 27
// Rounds: 26, numChars: 27
// Rounds: 27, numChars: 25
// Rounds: 28, numChars: 25
// Rounds: 29, numChars: 24
// Rounds: 30, numChars: 21
// Rounds: 31, numChars: 21
// Rounds: 32, numChars: 21
// Rounds: 33, numChars: 21
// Rounds: 34, numChars: 21
// Rounds: 35, numChars: 21
// Rounds: 36, numChars: 21
// Rounds: 37, numChars: 21
// Rounds: 38, numChars: 21
// Rounds: 39, numChars: 21
// Rounds: 40, numChars: 20
// Rounds: 41, numChars: 20
// Rounds: 42, numChars: 19
// Rounds: 43, numChars: 19
// Rounds: 44, numChars: 19
// Rounds: 45, numChars: 19
// Rounds: 46, numChars: 18
// Rounds: 47, numChars: 18
// Rounds: 48, numChars: 17
// Rounds: 49, numChars: 17
// Rounds: 50, numChars: 16
// Rounds: 51, numChars: 16
// Rounds: 52, numChars: 14
// Rounds: 53, numChars: 14
// Rounds: 54, numChars: 14
// Rounds: 55, numChars: 14
// Rounds: 56, numChars: 14
// Rounds: 57, numChars: 14
// Rounds: 58, numChars: 12
// Rounds: 59, numChars: 12
// Rounds: 60, numChars: 12
// Rounds: 61, numChars: 12
// Rounds: 62, numChars: 11
// Rounds: 63, numChars: 9
// Rounds: 64, numChars: 9
// Rounds: 65, numChars: 9
// Rounds: 66, numChars: 9
// Rounds: 67, numChars: 9
// Rounds: 68, numChars: 9
// Rounds: 69, numChars: 9
// Rounds: 70, numChars: 9
// Rounds: 71, numChars: 8
// Rounds: 72, numChars: 7
// Rounds: 73, numChars: 7
// Rounds: 74, numChars: 7
// Rounds: 75, numChars: 7
// Rounds: 76, numChars: 7
// Rounds: 77, numChars: 7
// Rounds: 78, numChars: 7
// Rounds: 79, numChars: 7
// Rounds: 80, numChars: 6
// AttackPower: 9
// Rounds: 1, numChars: 30
// Rounds: 2, numChars: 30
// Rounds: 3, numChars: 30
// Rounds: 4, numChars: 30
// Rounds: 5, numChars: 30
// Rounds: 6, numChars: 30
// Rounds: 7, numChars: 30
// Rounds: 8, numChars: 30
// Rounds: 9, numChars: 30
// Rounds: 10, numChars: 30
// Rounds: 11, numChars: 29
// Rounds: 12, numChars: 29
// Rounds: 13, numChars: 29
// Rounds: 14, numChars: 29
// Rounds: 15, numChars: 28
// Rounds: 16, numChars: 28
// Rounds: 17, numChars: 28
// Rounds: 18, numChars: 28
// Rounds: 19, numChars: 28
// Rounds: 20, numChars: 27
// Rounds: 21, numChars: 27
// Rounds: 22, numChars: 27
// Rounds: 23, numChars: 27
// Rounds: 24, numChars: 25
// Rounds: 25, numChars: 24
// Rounds: 26, numChars: 24
// Rounds: 27, numChars: 22
// Rounds: 28, numChars: 22
// Rounds: 29, numChars: 22
// Rounds: 30, numChars: 21
// Rounds: 31, numChars: 21
// Rounds: 32, numChars: 21
// Rounds: 33, numChars: 21
// Rounds: 34, numChars: 20
// Rounds: 35, numChars: 20
// Rounds: 36, numChars: 20
// Rounds: 37, numChars: 19
// Rounds: 38, numChars: 19
// Rounds: 39, numChars: 19
// Rounds: 40, numChars: 19
// Rounds: 41, numChars: 19
// Rounds: 42, numChars: 19
// Rounds: 43, numChars: 18
// Rounds: 44, numChars: 17
// Rounds: 45, numChars: 17
// Rounds: 46, numChars: 16
// Rounds: 47, numChars: 16
// Rounds: 48, numChars: 14
// Rounds: 49, numChars: 14
// Rounds: 50, numChars: 14
// Rounds: 51, numChars: 14
// Rounds: 52, numChars: 14
// Rounds: 53, numChars: 14
// Rounds: 54, numChars: 14
// Rounds: 55, numChars: 12
// Rounds: 56, numChars: 12
// Rounds: 57, numChars: 11
// Rounds: 58, numChars: 11
// Rounds: 59, numChars: 11
// Rounds: 60, numChars: 11
// Rounds: 61, numChars: 10
// Rounds: 62, numChars: 9
// Rounds: 63, numChars: 9
// Rounds: 64, numChars: 9
// Rounds: 65, numChars: 9
// Rounds: 66, numChars: 8
// Rounds: 67, numChars: 8
// Rounds: 68, numChars: 8
// Rounds: 69, numChars: 8
// Rounds: 70, numChars: 8
// Rounds: 71, numChars: 8
// Rounds: 72, numChars: 8
// Rounds: 73, numChars: 8
// Rounds: 74, numChars: 8
// Rounds: 75, numChars: 8
// Rounds: 76, numChars: 8
// Rounds: 77, numChars: 8
// Rounds: 78, numChars: 8
// Rounds: 79, numChars: 8
// Rounds: 80, numChars: 8
// Rounds: 80, numChars: 7
// AttackPower: 10
// Rounds: 1, numChars: 30
// Rounds: 2, numChars: 30
// Rounds: 3, numChars: 30
// Rounds: 4, numChars: 30
// Rounds: 5, numChars: 30
// Rounds: 6, numChars: 30
// Rounds: 7, numChars: 30
// Rounds: 8, numChars: 30
// Rounds: 9, numChars: 30
// Rounds: 10, numChars: 30
// Rounds: 11, numChars: 29
// Rounds: 12, numChars: 29
// Rounds: 13, numChars: 29
// Rounds: 14, numChars: 29
// Rounds: 15, numChars: 28
// Rounds: 16, numChars: 28
// Rounds: 17, numChars: 28
// Rounds: 18, numChars: 28
// Rounds: 19, numChars: 28
// Rounds: 20, numChars: 27
// Rounds: 21, numChars: 27
// Rounds: 22, numChars: 27
// Rounds: 23, numChars: 26
// Rounds: 24, numChars: 25
// Rounds: 25, numChars: 25
// Rounds: 26, numChars: 22
// Rounds: 27, numChars: 22
// Rounds: 28, numChars: 22
// Rounds: 29, numChars: 22
// Rounds: 30, numChars: 22
// Rounds: 31, numChars: 21
// Rounds: 32, numChars: 21
// Rounds: 33, numChars: 21
// Rounds: 34, numChars: 20
// Rounds: 35, numChars: 20
// Rounds: 36, numChars: 19
// Rounds: 37, numChars: 19
// Rounds: 38, numChars: 19
// Rounds: 39, numChars: 19
// Rounds: 40, numChars: 19
// Rounds: 41, numChars: 18
// Rounds: 42, numChars: 18
// Rounds: 43, numChars: 18
// Rounds: 44, numChars: 15
// Rounds: 45, numChars: 15
// Rounds: 46, numChars: 15
// Rounds: 47, numChars: 15
// Rounds: 48, numChars: 15
// Rounds: 49, numChars: 15
// Rounds: 50, numChars: 13
// Rounds: 51, numChars: 13
// Rounds: 52, numChars: 13
// Rounds: 53, numChars: 13
// Rounds: 54, numChars: 12
// Rounds: 55, numChars: 12
// Rounds: 56, numChars: 12
// Rounds: 57, numChars: 11
// Rounds: 58, numChars: 11
// Rounds: 59, numChars: 10
// Rounds: 60, numChars: 10
// Rounds: 61, numChars: 10
// Rounds: 62, numChars: 10
// Rounds: 63, numChars: 10
// Rounds: 64, numChars: 9
// Rounds: 65, numChars: 9
// Rounds: 66, numChars: 9
// Rounds: 67, numChars: 9
// Rounds: 68, numChars: 9
// Rounds: 68, numChars: 8
// AttackPower: 11
// Rounds: 1, numChars: 30
// Rounds: 2, numChars: 30
// Rounds: 3, numChars: 30
// Rounds: 4, numChars: 30
// Rounds: 5, numChars: 30
// Rounds: 6, numChars: 30
// Rounds: 7, numChars: 30
// Rounds: 8, numChars: 30
// Rounds: 9, numChars: 30
// Rounds: 10, numChars: 29
// Rounds: 11, numChars: 29
// Rounds: 12, numChars: 29
// Rounds: 13, numChars: 29
// Rounds: 14, numChars: 28
// Rounds: 15, numChars: 28
// Rounds: 16, numChars: 28
// Rounds: 17, numChars: 28
// Rounds: 18, numChars: 27
// Rounds: 19, numChars: 27
// Rounds: 20, numChars: 27
// Rounds: 21, numChars: 26
// Rounds: 22, numChars: 25
// Rounds: 23, numChars: 25
// Rounds: 24, numChars: 23
// Rounds: 25, numChars: 22
// Rounds: 26, numChars: 22
// Rounds: 27, numChars: 22
// Rounds: 28, numChars: 22
// Rounds: 29, numChars: 22
// Rounds: 30, numChars: 22
// Rounds: 31, numChars: 21
// Rounds: 32, numChars: 21
// Rounds: 33, numChars: 19
// Rounds: 34, numChars: 19
// Rounds: 35, numChars: 19
// Rounds: 36, numChars: 19
// Rounds: 37, numChars: 19
// Rounds: 38, numChars: 18
// Rounds: 39, numChars: 18
// Rounds: 40, numChars: 17
// Rounds: 41, numChars: 17
// Rounds: 42, numChars: 16
// Rounds: 43, numChars: 16
// Rounds: 44, numChars: 16
// Rounds: 45, numChars: 14
// Rounds: 46, numChars: 14
// Rounds: 47, numChars: 14
// Rounds: 48, numChars: 13
// Rounds: 49, numChars: 12
// Rounds: 50, numChars: 12
// Rounds: 51, numChars: 12
// Rounds: 52, numChars: 12
// Rounds: 53, numChars: 12
// Rounds: 54, numChars: 12
// Rounds: 55, numChars: 11
// Rounds: 56, numChars: 11
// Rounds: 57, numChars: 11
// Rounds: 58, numChars: 11
// Rounds: 59, numChars: 11
// Rounds: 60, numChars: 10
// Rounds: 61, numChars: 10
// Rounds: 62, numChars: 10
// Rounds: 63, numChars: 10
// Rounds: 64, numChars: 10
// Rounds: 65, numChars: 10
// Rounds: 66, numChars: 10
// Rounds: 67, numChars: 10
// Rounds: 68, numChars: 10
// Rounds: 69, numChars: 9
// Rounds: 70, numChars: 8
// Rounds: 71, numChars: 8
// Rounds: 72, numChars: 8
// Rounds: 73, numChars: 7
// Rounds: 74, numChars: 7
// Rounds: 75, numChars: 7
// Rounds: 76, numChars: 7
// Rounds: 77, numChars: 6
// AttackPower: 12
// Rounds: 1, numChars: 30
// Rounds: 2, numChars: 30
// Rounds: 3, numChars: 30
// Rounds: 4, numChars: 30
// Rounds: 5, numChars: 30
// Rounds: 6, numChars: 30
// Rounds: 7, numChars: 30
// Rounds: 8, numChars: 30
// Rounds: 9, numChars: 30
// Rounds: 10, numChars: 29
// Rounds: 11, numChars: 29
// Rounds: 12, numChars: 29
// Rounds: 13, numChars: 28
// Rounds: 14, numChars: 28
// Rounds: 15, numChars: 28
// Rounds: 16, numChars: 28
// Rounds: 17, numChars: 28
// Rounds: 18, numChars: 27
// Rounds: 19, numChars: 27
// Rounds: 20, numChars: 26
// Rounds: 21, numChars: 25
// Rounds: 22, numChars: 24
// Rounds: 23, numChars: 23
// Rounds: 24, numChars: 22
// Rounds: 25, numChars: 22
// Rounds: 26, numChars: 22
// Rounds: 27, numChars: 22
// Rounds: 28, numChars: 22
// Rounds: 29, numChars: 22
// Rounds: 30, numChars: 21
// Rounds: 31, numChars: 20
// Rounds: 32, numChars: 19
// Rounds: 33, numChars: 19
// Rounds: 34, numChars: 19
// Rounds: 35, numChars: 19
// Rounds: 36, numChars: 18
// Rounds: 37, numChars: 18
// Rounds: 38, numChars: 17
// Rounds: 39, numChars: 16
// Rounds: 40, numChars: 16
// Rounds: 41, numChars: 15
// Rounds: 42, numChars: 15
// Rounds: 43, numChars: 15
// Rounds: 44, numChars: 13
// Rounds: 45, numChars: 13
// Rounds: 46, numChars: 13
// Rounds: 47, numChars: 13
// Rounds: 48, numChars: 12
// Rounds: 49, numChars: 12
// Rounds: 50, numChars: 11
// Rounds: 51, numChars: 11
// Rounds: 52, numChars: 10
// Rounds: 53, numChars: 9
// Rounds: 54, numChars: 9
// Rounds: 55, numChars: 9
// Rounds: 56, numChars: 9
// Rounds: 57, numChars: 8
// AttackPower: 13
// Rounds: 1, numChars: 30
// Rounds: 2, numChars: 30
// Rounds: 3, numChars: 30
// Rounds: 4, numChars: 30
// Rounds: 5, numChars: 30
// Rounds: 6, numChars: 30
// Rounds: 7, numChars: 30
// Rounds: 8, numChars: 30
// Rounds: 9, numChars: 29
// Rounds: 10, numChars: 29
// Rounds: 11, numChars: 29
// Rounds: 12, numChars: 29
// Rounds: 13, numChars: 28
// Rounds: 14, numChars: 28
// Rounds: 15, numChars: 28
// Rounds: 16, numChars: 28
// Rounds: 17, numChars: 27
// Rounds: 18, numChars: 27
// Rounds: 19, numChars: 26
// Rounds: 20, numChars: 25
// Rounds: 21, numChars: 25
// Rounds: 22, numChars: 24
// Rounds: 23, numChars: 22
// Rounds: 24, numChars: 22
// Rounds: 25, numChars: 22
// Rounds: 26, numChars: 22
// Rounds: 27, numChars: 22
// Rounds: 28, numChars: 22
// Rounds: 29, numChars: 22
// Rounds: 30, numChars: 21
// Rounds: 31, numChars: 19
// Rounds: 32, numChars: 19
// Rounds: 33, numChars: 19
// Rounds: 34, numChars: 19
// Rounds: 35, numChars: 18
// Rounds: 36, numChars: 17
// Rounds: 37, numChars: 17
// Rounds: 38, numChars: 17
// Rounds: 39, numChars: 16
// Rounds: 40, numChars: 16
// Rounds: 41, numChars: 16
// Rounds: 42, numChars: 16
// Rounds: 43, numChars: 14
// Rounds: 44, numChars: 13
// Rounds: 45, numChars: 13
// Rounds: 46, numChars: 11
// Rounds: 47, numChars: 11
// Rounds: 48, numChars: 11
// Rounds: 49, numChars: 11
// Rounds: 50, numChars: 11
// Rounds: 51, numChars: 11
// Rounds: 52, numChars: 11
// Rounds: 53, numChars: 10
// Rounds: 54, numChars: 10
// Rounds: 55, numChars: 10
// Rounds: 56, numChars: 9
// Rounds: 57, numChars: 9
// Rounds: 58, numChars: 9
// Rounds: 59, numChars: 9
// Rounds: 60, numChars: 9
// Rounds: 61, numChars: 8
// AttackPower: 14
// Rounds: 1, numChars: 30
// Rounds: 2, numChars: 30
// Rounds: 3, numChars: 30
// Rounds: 4, numChars: 30
// Rounds: 5, numChars: 30
// Rounds: 6, numChars: 30
// Rounds: 7, numChars: 30
// Rounds: 8, numChars: 30
// Rounds: 9, numChars: 29
// Rounds: 10, numChars: 29
// Rounds: 11, numChars: 29
// Rounds: 12, numChars: 28
// Rounds: 13, numChars: 28
// Rounds: 14, numChars: 28
// Rounds: 15, numChars: 28
// Rounds: 16, numChars: 27
// Rounds: 17, numChars: 27
// Rounds: 18, numChars: 26
// Rounds: 19, numChars: 26
// Rounds: 20, numChars: 25
// Rounds: 21, numChars: 23
// Rounds: 22, numChars: 22
// Rounds: 23, numChars: 22
// Rounds: 24, numChars: 22
// Rounds: 25, numChars: 22
// Rounds: 26, numChars: 22
// Rounds: 27, numChars: 21
// Rounds: 28, numChars: 21
// Rounds: 29, numChars: 20
// Rounds: 30, numChars: 19
// Rounds: 31, numChars: 18
// Rounds: 32, numChars: 18
// Rounds: 33, numChars: 18
// Rounds: 34, numChars: 16
// Rounds: 35, numChars: 15
// Rounds: 36, numChars: 14
// Rounds: 37, numChars: 14
// Rounds: 38, numChars: 13
// Rounds: 39, numChars: 12
// Rounds: 40, numChars: 12
// Rounds: 41, numChars: 12
// Rounds: 42, numChars: 12
// Rounds: 43, numChars: 12
// Rounds: 44, numChars: 12
// Rounds: 45, numChars: 12
// Rounds: 46, numChars: 11
// Rounds: 47, numChars: 11
// Rounds: 48, numChars: 10
// Rounds: 49, numChars: 10
// Rounds: 50, numChars: 10
// Rounds: 51, numChars: 10
// Rounds: 52, numChars: 10
// Rounds: 53, numChars: 10
// Rounds: 53, numChars: 9
// AttackPower: 15
// Rounds: 1, numChars: 30
// Rounds: 2, numChars: 30
// Rounds: 3, numChars: 30
// Rounds: 4, numChars: 30
// Rounds: 5, numChars: 30
// Rounds: 6, numChars: 30
// Rounds: 7, numChars: 30
// Rounds: 8, numChars: 30
// Rounds: 9, numChars: 29
// Rounds: 10, numChars: 29
// Rounds: 11, numChars: 29
// Rounds: 12, numChars: 28
// Rounds: 13, numChars: 28
// Rounds: 14, numChars: 28
// Rounds: 15, numChars: 28
// Rounds: 16, numChars: 27
// Rounds: 17, numChars: 26
// Rounds: 18, numChars: 26
// Rounds: 19, numChars: 25
// Rounds: 20, numChars: 24
// Rounds: 21, numChars: 22
// Rounds: 22, numChars: 22
// Rounds: 23, numChars: 22
// Rounds: 24, numChars: 22
// Rounds: 25, numChars: 22
// Rounds: 26, numChars: 22
// Rounds: 27, numChars: 21
// Rounds: 28, numChars: 20
// Rounds: 29, numChars: 20
// Rounds: 30, numChars: 19
// Rounds: 31, numChars: 19
// Rounds: 32, numChars: 16
// Rounds: 33, numChars: 16
// Rounds: 34, numChars: 16
// Rounds: 35, numChars: 15
// Rounds: 36, numChars: 15
// Rounds: 37, numChars: 15
// Rounds: 38, numChars: 15
// Rounds: 39, numChars: 14
// Rounds: 40, numChars: 13
// Rounds: 41, numChars: 12
// Rounds: 42, numChars: 12
// Rounds: 43, numChars: 11
// Rounds: 44, numChars: 11
// Rounds: 45, numChars: 10
// Rounds: 46, numChars: 10
// Rounds: 47, numChars: 10
// Rounds: 48, numChars: 10
// Rounds: 48, numChars: 9
// AttackPower: 16
// Rounds: 1, numChars: 30
// Rounds: 2, numChars: 30
// Rounds: 3, numChars: 30
// Rounds: 4, numChars: 30
// Rounds: 5, numChars: 30
// Rounds: 6, numChars: 30
// Rounds: 7, numChars: 30
// Rounds: 8, numChars: 29
// Rounds: 9, numChars: 29
// Rounds: 10, numChars: 29
// Rounds: 11, numChars: 28
// Rounds: 12, numChars: 28
// Rounds: 13, numChars: 28
// Rounds: 14, numChars: 28
// Rounds: 15, numChars: 27
// Rounds: 16, numChars: 26
// Rounds: 17, numChars: 26
// Rounds: 18, numChars: 25
// Rounds: 19, numChars: 23
// Rounds: 20, numChars: 22
// Rounds: 21, numChars: 22
// Rounds: 22, numChars: 22
// Rounds: 23, numChars: 22
// Rounds: 24, numChars: 21
// Rounds: 25, numChars: 21
// Rounds: 26, numChars: 20
// Rounds: 27, numChars: 20
// Rounds: 28, numChars: 19
// Rounds: 29, numChars: 19
// Rounds: 30, numChars: 18
// Rounds: 31, numChars: 17
// Rounds: 32, numChars: 16
// Rounds: 33, numChars: 15
// Rounds: 34, numChars: 13
// Rounds: 35, numChars: 13
// Rounds: 36, numChars: 11
// Rounds: 37, numChars: 11
// Rounds: 38, numChars: 11
// Rounds: 39, numChars: 11
// Rounds: 40, numChars: 11
// Rounds: 41, numChars: 10
// Rounds: 42, numChars: 10
// Rounds: 43, numChars: 10
// Rounds: 44, numChars: 10
// Rounds: 44, numChars: 9
// AttackPower: 17
// Rounds: 1, numChars: 30
// Rounds: 2, numChars: 30
// Rounds: 3, numChars: 30
// Rounds: 4, numChars: 30
// Rounds: 5, numChars: 30
// Rounds: 6, numChars: 30
// Rounds: 7, numChars: 30
// Rounds: 8, numChars: 29
// Rounds: 9, numChars: 29
// Rounds: 10, numChars: 29
// Rounds: 11, numChars: 28
// Rounds: 12, numChars: 28
// Rounds: 13, numChars: 28
// Rounds: 14, numChars: 28
// Rounds: 15, numChars: 27
// Rounds: 16, numChars: 26
// Rounds: 17, numChars: 26
// Rounds: 18, numChars: 25
// Rounds: 19, numChars: 23
// Rounds: 20, numChars: 22
// Rounds: 21, numChars: 22
// Rounds: 22, numChars: 22
// Rounds: 23, numChars: 22
// Rounds: 24, numChars: 21
// Rounds: 25, numChars: 21
// Rounds: 26, numChars: 20
// Rounds: 27, numChars: 20
// Rounds: 28, numChars: 19
// Rounds: 29, numChars: 19
// Rounds: 30, numChars: 18
// Rounds: 31, numChars: 17
// Rounds: 32, numChars: 16
// Rounds: 33, numChars: 15
// Rounds: 34, numChars: 13
// Rounds: 35, numChars: 13
// Rounds: 36, numChars: 11
// Rounds: 37, numChars: 11
// Rounds: 38, numChars: 11
// Rounds: 39, numChars: 11
// Rounds: 40, numChars: 11
// Rounds: 41, numChars: 10
// Rounds: 42, numChars: 10
// Rounds: 43, numChars: 10
// Rounds: 44, numChars: 10
// Rounds: 44, numChars: 9
// AttackPower: 18
// Rounds: 1, numChars: 30
// Rounds: 2, numChars: 30
// Rounds: 3, numChars: 30
// Rounds: 4, numChars: 30
// Rounds: 5, numChars: 30
// Rounds: 6, numChars: 30
// Rounds: 7, numChars: 30
// Rounds: 8, numChars: 29
// Rounds: 9, numChars: 29
// Rounds: 10, numChars: 29
// Rounds: 11, numChars: 28
// Rounds: 12, numChars: 28
// Rounds: 13, numChars: 28
// Rounds: 14, numChars: 27
// Rounds: 15, numChars: 26
// Rounds: 16, numChars: 26
// Rounds: 17, numChars: 25
// Rounds: 18, numChars: 24
// Rounds: 19, numChars: 23
// Rounds: 20, numChars: 22
// Rounds: 21, numChars: 22
// Rounds: 22, numChars: 22
// Rounds: 23, numChars: 22
// Rounds: 24, numChars: 21
// Rounds: 25, numChars: 20
// Rounds: 26, numChars: 20
// Rounds: 27, numChars: 20
// Rounds: 28, numChars: 18
// Rounds: 29, numChars: 18
// Rounds: 30, numChars: 18
// Rounds: 31, numChars: 17
// Rounds: 32, numChars: 15
// Rounds: 33, numChars: 14
// Rounds: 34, numChars: 13
// Rounds: 35, numChars: 13
// Rounds: 36, numChars: 13
// Rounds: 37, numChars: 11
// Rounds: 37, numChars: 10
// AttackPower: 19
// elvesDied: Boolean = false
// attackPower: Int = 19
// res12_3: Int = 52133

// %%
characters
// Out:
// res13: ListBuffer[Character] = ListBuffer(
//   E - Remaining health: 86 . Currently at (18, 11),
//   E - Remaining health: 125 . Currently at (20, 11),
//   E - Remaining health: 167 . Currently at (19, 9),
//   E - Remaining health: 158 . Currently at (13, 21),
//   E - Remaining health: 176 . Currently at (19, 10),
//   E - Remaining health: 137 . Currently at (12, 22),
//   E - Remaining health: 200 . Currently at (21, 14),
//   E - Remaining health: 200 . Currently at (13, 22),
//   E - Remaining health: 5 . Currently at (10, 20),
//   E - Remaining health: 155 . Currently at (11, 21)
// )
