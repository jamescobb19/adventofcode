# %%
from datetime import datetime
from collections import defaultdict
import math

# %%
def parse(line):
    # Don't care about the year or the hour, just the day/month and offset from midnight (+/- 60 mins)
    # [1518-10-12 00:31] falls asleep
    # [1518-10-03 00:54] wakes up
    # [1518-08-07 00:00] Guard #3491 begins shift
    # Action is either wake for waking up, sleep for falling asleep, or #id for shift start
    splitLine = line.split(' ')
    dateString, timeString, text = splitLine[0], splitLine[1], splitLine[2:]
    dateString = dateString.split('-')
    hour, minute = timeString[:-1].split(':')
    hour = (24-int(hour))%24
    if 'wakes' in text:
        action = 'wake'
    elif 'asleep\n' in text:
        action = 'sleep'
    else:
        action = text[1]
    offset = int(minute) - (hour*60)
    return {
        'month': int(dateString[1]),
        'day': int(dateString[2]) - math.floor(offset / 60),
        'offset': offset,
        'action': action
    }

# %%
with open('ryanInput') as f:
    lines = [(line, parse(line)) for line in f.readlines()]

# %%
sortedLines = sorted(lines, key=lambda line: (line[1]['month'], line[1]['day'], line[1]['offset']))

# %%
sleepCounter = defaultdict(lambda: defaultdict(int))

# %%
testLines = sortedLines[:4]

# %%
# Non-parallel method (relies on no missing/jumbled data)
for originalLine, line in sortedLines:
    print(originalLine)
    print(line)
    action = line['action']
    if '#' in action:
        print('Changing guard to', action)
        currentGuard = action
    else:
        if action == 'sleep':
            sleepStart = line['offset']
            print('Starting sleep at minute', sleepStart)
        else:  # action == wake
            print('Updating counter between {} and {}'.format(sleepStart, line['offset']))
            for minute in range(sleepStart, line['offset']):
                sleepCounter[currentGuard][minute] += 1
# Out:
# [1518-03-04 00:04] Guard #1307 begins shift
#
# {'month': 3, 'day': 4, 'offset': 4, 'action': '#1307'}
# Changing guard to #1307
# [1518-03-04 00:08] falls asleep
#
# {'month': 3, 'day': 4, 'offset': 8, 'action': 'sleep'}
# Starting sleep at minute 8
# [1518-03-04 00:35] wakes up
#
# {'month': 3, 'day': 4, 'offset': 35, 'action': 'wake'}
# Updating counter between 8 and 35
# [1518-03-04 00:54] falls asleep
#
# {'month': 3, 'day': 4, 'offset': 54, 'action': 'sleep'}
# Starting sleep at minute 54
# [1518-03-04 00:59] wakes up
#
# {'month': 3, 'day': 4, 'offset': 59, 'action': 'wake'}
# Updating counter between 54 and 59
# [1518-03-05 00:03] Guard #691 begins shift
#
# {'month': 3, 'day': 5, 'offset': 3, 'action': '#691'}
# Changing guard to #691
# [1518-03-05 00:25] falls asleep
#
# {'month': 3, 'day': 5, 'offset': 25, 'action': 'sleep'}
# Starting sleep at minute 25
# [1518-03-05 00:30] wakes up
#
# {'month': 3, 'day': 5, 'offset': 30, 'action': 'wake'}
# Updating counter between 25 and 30
# [1518-03-05 00:47] falls asleep
#
# {'month': 3, 'day': 5, 'offset': 47, 'action': 'sleep'}
# Starting sleep at minute 47
# [1518-03-05 00:55] wakes up
#
# {'month': 3, 'day': 5, 'offset': 55, 'action': 'wake'}
# Updating counter between 47 and 55
# [1518-03-05 23:59] Guard #1307 begins shift
#
# {'month': 3, 'day': 6, 'offset': -1, 'action': '#1307'}
# Changing guard to #1307
# [1518-03-06 00:53] falls asleep
#
# {'month': 3, 'day': 6, 'offset': 53, 'action': 'sleep'}
# Starting sleep at minute 53
# [1518-03-06 00:59] wakes up
#
# {'month': 3, 'day': 6, 'offset': 59, 'action': 'wake'}
# Updating counter between 53 and 59
# [1518-03-07 00:00] Guard #2399 begins shift
#
# {'month': 3, 'day': 7, 'offset': 0, 'action': '#2399'}
# Changing guard to #2399
# [1518-03-07 00:15] falls asleep
#
# {'month': 3, 'day': 7, 'offset': 15, 'action': 'sleep'}
# Starting sleep at minute 15
# [1518-03-07 00:24] wakes up
#
# {'month': 3, 'day': 7, 'offset': 24, 'action': 'wake'}
# Updating counter between 15 and 24
# [1518-03-07 00:39] falls asleep
#
# {'month': 3, 'day': 7, 'offset': 39, 'action': 'sleep'}
# Starting sleep at minute 39
# [1518-03-07 00:47] wakes up
#
# {'month': 3, 'day': 7, 'offset': 47, 'action': 'wake'}
# Updating counter between 39 and 47
# [1518-03-08 00:02] Guard #2851 begins shift
#
# {'month': 3, 'day': 8, 'offset': 2, 'action': '#2851'}
# Changing guard to #2851
# [1518-03-08 00:17] falls asleep
#
# {'month': 3, 'day': 8, 'offset': 17, 'action': 'sleep'}
# Starting sleep at minute 17
# [1518-03-08 00:20] wakes up
#
# {'month': 3, 'day': 8, 'offset': 20, 'action': 'wake'}
# Updating counter between 17 and 20
# [1518-03-08 00:35] falls asleep
#
# {'month': 3, 'day': 8, 'offset': 35, 'action': 'sleep'}
# Starting sleep at minute 35
# [1518-03-08 00:36] wakes up
#
# {'month': 3, 'day': 8, 'offset': 36, 'action': 'wake'}
# Updating counter between 35 and 36
# [1518-03-08 00:42] falls asleep
#
# {'month': 3, 'day': 8, 'offset': 42, 'action': 'sleep'}
# Starting sleep at minute 42
# [1518-03-08 00:54] wakes up
#
# {'month': 3, 'day': 8, 'offset': 54, 'action': 'wake'}
# Updating counter between 42 and 54
# [1518-03-08 23:50] Guard #1051 begins shift
#
# {'month': 3, 'day': 9, 'offset': -10, 'action': '#1051'}
# Changing guard to #1051
# [1518-03-09 00:03] falls asleep
#
# {'month': 3, 'day': 9, 'offset': 3, 'action': 'sleep'}
# Starting sleep at minute 3
# [1518-03-09 00:34] wakes up
#
# {'month': 3, 'day': 9, 'offset': 34, 'action': 'wake'}
# Updating counter between 3 and 34
# [1518-03-09 00:37] falls asleep
#
# {'month': 3, 'day': 9, 'offset': 37, 'action': 'sleep'}
# Starting sleep at minute 37
# [1518-03-09 00:55] wakes up
#
# {'month': 3, 'day': 9, 'offset': 55, 'action': 'wake'}
# Updating counter between 37 and 55
# [1518-03-09 23:56] Guard #2267 begins shift
#
# {'month': 3, 'day': 10, 'offset': -4, 'action': '#2267'}
# Changing guard to #2267
# [1518-03-10 00:12] falls asleep
#
# {'month': 3, 'day': 10, 'offset': 12, 'action': 'sleep'}
# Starting sleep at minute 12
# [1518-03-10 00:32] wakes up
#
# {'month': 3, 'day': 10, 'offset': 32, 'action': 'wake'}
# Updating counter between 12 and 32
# [1518-03-10 00:36] falls asleep
#
# {'month': 3, 'day': 10, 'offset': 36, 'action': 'sleep'}
# Starting sleep at minute 36
# [1518-03-10 00:44] wakes up
#
# {'month': 3, 'day': 10, 'offset': 44, 'action': 'wake'}
# Updating counter between 36 and 44
# [1518-03-10 23:51] Guard #349 begins shift
#
# {'month': 3, 'day': 11, 'offset': -9, 'action': '#349'}
# Changing guard to #349
# [1518-03-11 00:00] falls asleep
#
# {'month': 3, 'day': 11, 'offset': 0, 'action': 'sleep'}
# Starting sleep at minute 0
# [1518-03-11 00:40] wakes up
#
# {'month': 3, 'day': 11, 'offset': 40, 'action': 'wake'}
# Updating counter between 0 and 40
# [1518-03-12 00:01] Guard #1601 begins shift
#
# {'month': 3, 'day': 12, 'offset': 1, 'action': '#1601'}
# Changing guard to #1601
# [1518-03-12 00:06] falls asleep
#
# {'month': 3, 'day': 12, 'offset': 6, 'action': 'sleep'}
# Starting sleep at minute 6
# [1518-03-12 00:16] wakes up
#
# {'month': 3, 'day': 12, 'offset': 16, 'action': 'wake'}
# Updating counter between 6 and 16
# [1518-03-12 00:53] falls asleep
#
# {'month': 3, 'day': 12, 'offset': 53, 'action': 'sleep'}
# Starting sleep at minute 53
# [1518-03-12 00:59] wakes up
#
# {'month': 3, 'day': 12, 'offset': 59, 'action': 'wake'}
# Updating counter between 53 and 59
# [1518-03-13 00:00] Guard #2153 begins shift
#
# {'month': 3, 'day': 13, 'offset': 0, 'action': '#2153'}
# Changing guard to #2153
# [1518-03-13 00:15] falls asleep
#
# {'month': 3, 'day': 13, 'offset': 15, 'action': 'sleep'}
# Starting sleep at minute 15
# [1518-03-13 00:45] wakes up
#
# {'month': 3, 'day': 13, 'offset': 45, 'action': 'wake'}
# Updating counter between 15 and 45
# [1518-03-14 00:03] Guard #2851 begins shift
#
# {'month': 3, 'day': 14, 'offset': 3, 'action': '#2851'}
# Changing guard to #2851
# [1518-03-14 00:07] falls asleep
#
# {'month': 3, 'day': 14, 'offset': 7, 'action': 'sleep'}
# Starting sleep at minute 7
# [1518-03-14 00:51] wakes up
#
# {'month': 3, 'day': 14, 'offset': 51, 'action': 'wake'}
# Updating counter between 7 and 51
# [1518-03-14 23:50] Guard #1307 begins shift
#
# {'month': 3, 'day': 15, 'offset': -10, 'action': '#1307'}
# Changing guard to #1307
# [1518-03-15 00:02] falls asleep
#
# {'month': 3, 'day': 15, 'offset': 2, 'action': 'sleep'}
# Starting sleep at minute 2
# [1518-03-15 00:48] wakes up
#
# {'month': 3, 'day': 15, 'offset': 48, 'action': 'wake'}
# Updating counter between 2 and 48
# [1518-03-15 00:51] falls asleep
#
# {'month': 3, 'day': 15, 'offset': 51, 'action': 'sleep'}
# Starting sleep at minute 51
# [1518-03-15 00:57] wakes up
#
# {'month': 3, 'day': 15, 'offset': 57, 'action': 'wake'}
# Updating counter between 51 and 57
# [1518-03-15 23:57] Guard #2267 begins shift
#
# {'month': 3, 'day': 16, 'offset': -3, 'action': '#2267'}
# Changing guard to #2267
# [1518-03-16 00:07] falls asleep
#
# {'month': 3, 'day': 16, 'offset': 7, 'action': 'sleep'}
# Starting sleep at minute 7
# [1518-03-16 00:20] wakes up
#
# {'month': 3, 'day': 16, 'offset': 20, 'action': 'wake'}
# Updating counter between 7 and 20
# [1518-03-16 00:26] falls asleep
#
# {'month': 3, 'day': 16, 'offset': 26, 'action': 'sleep'}
# Starting sleep at minute 26
# [1518-03-16 00:58] wakes up
#
# {'month': 3, 'day': 16, 'offset': 58, 'action': 'wake'}
# Updating counter between 26 and 58
# [1518-03-17 00:01] Guard #2267 begins shift
#
# {'month': 3, 'day': 17, 'offset': 1, 'action': '#2267'}
# Changing guard to #2267
# [1518-03-17 00:09] falls asleep
#
# {'month': 3, 'day': 17, 'offset': 9, 'action': 'sleep'}
# Starting sleep at minute 9
# [1518-03-17 00:11] wakes up
#
# {'month': 3, 'day': 17, 'offset': 11, 'action': 'wake'}
# Updating counter between 9 and 11
# [1518-03-17 00:27] falls asleep
#
# {'month': 3, 'day': 17, 'offset': 27, 'action': 'sleep'}
# Starting sleep at minute 27
# [1518-03-17 00:28] wakes up
#
# {'month': 3, 'day': 17, 'offset': 28, 'action': 'wake'}
# Updating counter between 27 and 28
# [1518-03-17 00:31] falls asleep
#
# {'month': 3, 'day': 17, 'offset': 31, 'action': 'sleep'}
# Starting sleep at minute 31
# [1518-03-17 00:38] wakes up
#
# {'month': 3, 'day': 17, 'offset': 38, 'action': 'wake'}
# Updating counter between 31 and 38
# [1518-03-17 00:41] falls asleep
#
# {'month': 3, 'day': 17, 'offset': 41, 'action': 'sleep'}
# Starting sleep at minute 41
# [1518-03-17 00:53] wakes up
#
# {'month': 3, 'day': 17, 'offset': 53, 'action': 'wake'}
# Updating counter between 41 and 53
# [1518-03-18 00:04] Guard #2447 begins shift
#
# {'month': 3, 'day': 18, 'offset': 4, 'action': '#2447'}
# Changing guard to #2447
# [1518-03-18 00:13] falls asleep
#
# {'month': 3, 'day': 18, 'offset': 13, 'action': 'sleep'}
# Starting sleep at minute 13
# [1518-03-18 00:28] wakes up
#
# {'month': 3, 'day': 18, 'offset': 28, 'action': 'wake'}
# Updating counter between 13 and 28
# [1518-03-18 00:37] falls asleep
#
# {'month': 3, 'day': 18, 'offset': 37, 'action': 'sleep'}
# Starting sleep at minute 37
# [1518-03-18 00:39] wakes up
#
# {'month': 3, 'day': 18, 'offset': 39, 'action': 'wake'}
# Updating counter between 37 and 39
# [1518-03-18 00:57] falls asleep
#
# {'month': 3, 'day': 18, 'offset': 57, 'action': 'sleep'}
# Starting sleep at minute 57
# [1518-03-18 00:59] wakes up
#
# {'month': 3, 'day': 18, 'offset': 59, 'action': 'wake'}
# Updating counter between 57 and 59
# [1518-03-18 23:57] Guard #1307 begins shift
#
# {'month': 3, 'day': 19, 'offset': -3, 'action': '#1307'}
# Changing guard to #1307
# [1518-03-19 00:45] falls asleep
#
# {'month': 3, 'day': 19, 'offset': 45, 'action': 'sleep'}
# Starting sleep at minute 45
# [1518-03-19 00:55] wakes up
#
# {'month': 3, 'day': 19, 'offset': 55, 'action': 'wake'}
# Updating counter between 45 and 55
# [1518-03-19 23:59] Guard #1153 begins shift
#
# {'month': 3, 'day': 20, 'offset': -1, 'action': '#1153'}
# Changing guard to #1153
# [1518-03-21 00:03] Guard #2333 begins shift
#
# {'month': 3, 'day': 21, 'offset': 3, 'action': '#2333'}
# Changing guard to #2333
# [1518-03-21 00:16] falls asleep
#
# {'month': 3, 'day': 21, 'offset': 16, 'action': 'sleep'}
# Starting sleep at minute 16
# [1518-03-21 00:28] wakes up
#
# {'month': 3, 'day': 21, 'offset': 28, 'action': 'wake'}
# Updating counter between 16 and 28
# [1518-03-22 00:00] Guard #1117 begins shift
#
# {'month': 3, 'day': 22, 'offset': 0, 'action': '#1117'}
# Changing guard to #1117
# [1518-03-22 00:24] falls asleep
#
# {'month': 3, 'day': 22, 'offset': 24, 'action': 'sleep'}
# Starting sleep at minute 24
# [1518-03-22 00:32] wakes up
#
# {'month': 3, 'day': 22, 'offset': 32, 'action': 'wake'}
# Updating counter between 24 and 32
# [1518-03-22 00:42] falls asleep
#
# {'month': 3, 'day': 22, 'offset': 42, 'action': 'sleep'}
# Starting sleep at minute 42
# [1518-03-22 00:56] wakes up
#
# {'month': 3, 'day': 22, 'offset': 56, 'action': 'wake'}
# Updating counter between 42 and 56
# [1518-03-23 00:03] Guard #509 begins shift
#
# {'month': 3, 'day': 23, 'offset': 3, 'action': '#509'}
# Changing guard to #509
# [1518-03-23 00:14] falls asleep
#
# {'month': 3, 'day': 23, 'offset': 14, 'action': 'sleep'}
# Starting sleep at minute 14
# [1518-03-23 00:35] wakes up
#
# {'month': 3, 'day': 23, 'offset': 35, 'action': 'wake'}
# Updating counter between 14 and 35
# [1518-03-23 23:57] Guard #1091 begins shift
#
# {'month': 3, 'day': 24, 'offset': -3, 'action': '#1091'}
# Changing guard to #1091
# [1518-03-24 00:21] falls asleep
#
# {'month': 3, 'day': 24, 'offset': 21, 'action': 'sleep'}
# Starting sleep at minute 21
# [1518-03-24 00:43] wakes up
#
# {'month': 3, 'day': 24, 'offset': 43, 'action': 'wake'}
# Updating counter between 21 and 43
# [1518-03-25 00:00] Guard #2851 begins shift
#
# {'month': 3, 'day': 25, 'offset': 0, 'action': '#2851'}
# Changing guard to #2851
# [1518-03-25 00:26] falls asleep
#
# {'month': 3, 'day': 25, 'offset': 26, 'action': 'sleep'}
# Starting sleep at minute 26
# [1518-03-25 00:31] wakes up
#
# {'month': 3, 'day': 25, 'offset': 31, 'action': 'wake'}
# Updating counter between 26 and 31
# [1518-03-25 23:50] Guard #163 begins shift
#
# {'month': 3, 'day': 26, 'offset': -10, 'action': '#163'}
# Changing guard to #163
# [1518-03-26 00:03] falls asleep
#
# {'month': 3, 'day': 26, 'offset': 3, 'action': 'sleep'}
# Starting sleep at minute 3
# [1518-03-26 00:47] wakes up
#
# {'month': 3, 'day': 26, 'offset': 47, 'action': 'wake'}
# Updating counter between 3 and 47
# [1518-03-26 23:48] Guard #2851 begins shift
#
# {'month': 3, 'day': 27, 'offset': -12, 'action': '#2851'}
# Changing guard to #2851
# [1518-03-27 00:02] falls asleep
#
# {'month': 3, 'day': 27, 'offset': 2, 'action': 'sleep'}
# Starting sleep at minute 2
# [1518-03-27 00:09] wakes up
#
# {'month': 3, 'day': 27, 'offset': 9, 'action': 'wake'}
# Updating counter between 2 and 9
# [1518-03-27 00:15] falls asleep
#
# {'month': 3, 'day': 27, 'offset': 15, 'action': 'sleep'}
# Starting sleep at minute 15
# [1518-03-27 00:39] wakes up
#
# {'month': 3, 'day': 27, 'offset': 39, 'action': 'wake'}
# Updating counter between 15 and 39
# [1518-03-27 00:46] falls asleep
#
# {'month': 3, 'day': 27, 'offset': 46, 'action': 'sleep'}
# Starting sleep at minute 46
# [1518-03-27 00:59] wakes up
#
# {'month': 3, 'day': 27, 'offset': 59, 'action': 'wake'}
# Updating counter between 46 and 59
# [1518-03-28 00:01] Guard #163 begins shift
#
# {'month': 3, 'day': 28, 'offset': 1, 'action': '#163'}
# Changing guard to #163
# [1518-03-28 00:17] falls asleep
#
# {'month': 3, 'day': 28, 'offset': 17, 'action': 'sleep'}
# Starting sleep at minute 17
# [1518-03-28 00:38] wakes up
#
# {'month': 3, 'day': 28, 'offset': 38, 'action': 'wake'}
# Updating counter between 17 and 38
# [1518-03-28 23:58] Guard #1307 begins shift
#
# {'month': 3, 'day': 29, 'offset': -2, 'action': '#1307'}
# Changing guard to #1307
# [1518-03-29 00:19] falls asleep
#
# {'month': 3, 'day': 29, 'offset': 19, 'action': 'sleep'}
# Starting sleep at minute 19
# [1518-03-29 00:54] wakes up
#
# {'month': 3, 'day': 29, 'offset': 54, 'action': 'wake'}
# Updating counter between 19 and 54
# [1518-03-30 00:00] Guard #353 begins shift
#
# {'month': 3, 'day': 30, 'offset': 0, 'action': '#353'}
# Changing guard to #353
# [1518-03-30 00:18] falls asleep
#
# {'month': 3, 'day': 30, 'offset': 18, 'action': 'sleep'}
# Starting sleep at minute 18
# [1518-03-30 00:37] wakes up
#
# {'month': 3, 'day': 30, 'offset': 37, 'action': 'wake'}
# Updating counter between 18 and 37
# [1518-03-30 23:58] Guard #2447 begins shift
#
# {'month': 3, 'day': 31, 'offset': -2, 'action': '#2447'}
# Changing guard to #2447
# [1518-03-31 00:07] falls asleep
#
# {'month': 3, 'day': 31, 'offset': 7, 'action': 'sleep'}
# Starting sleep at minute 7
# [1518-03-31 00:30] wakes up
#
# {'month': 3, 'day': 31, 'offset': 30, 'action': 'wake'}
# Updating counter between 7 and 30
# [1518-03-31 23:51] Guard #163 begins shift
#
# {'month': 3, 'day': 32, 'offset': -9, 'action': '#163'}
# Changing guard to #163
# [1518-04-01 00:05] falls asleep
#
# {'month': 4, 'day': 1, 'offset': 5, 'action': 'sleep'}
# Starting sleep at minute 5
# [1518-04-01 00:41] wakes up
#
# {'month': 4, 'day': 1, 'offset': 41, 'action': 'wake'}
# Updating counter between 5 and 41
# [1518-04-01 23:57] Guard #163 begins shift
#
# {'month': 4, 'day': 2, 'offset': -3, 'action': '#163'}
# Changing guard to #163
# [1518-04-02 00:12] falls asleep
#
# {'month': 4, 'day': 2, 'offset': 12, 'action': 'sleep'}
# Starting sleep at minute 12
# [1518-04-02 00:33] wakes up
#
# {'month': 4, 'day': 2, 'offset': 33, 'action': 'wake'}
# Updating counter between 12 and 33
# [1518-04-03 00:00] Guard #2447 begins shift
#
# {'month': 4, 'day': 3, 'offset': 0, 'action': '#2447'}
# Changing guard to #2447
# [1518-04-03 00:07] falls asleep
#
# {'month': 4, 'day': 3, 'offset': 7, 'action': 'sleep'}
# Starting sleep at minute 7
# [1518-04-03 00:21] wakes up
#
# {'month': 4, 'day': 3, 'offset': 21, 'action': 'wake'}
# Updating counter between 7 and 21
# [1518-04-03 00:30] falls asleep
#
# {'month': 4, 'day': 3, 'offset': 30, 'action': 'sleep'}
# Starting sleep at minute 30
# [1518-04-03 00:58] wakes up
#
# {'month': 4, 'day': 3, 'offset': 58, 'action': 'wake'}
# Updating counter between 30 and 58
# [1518-04-03 23:51] Guard #163 begins shift
#
# {'month': 4, 'day': 4, 'offset': -9, 'action': '#163'}
# Changing guard to #163
# [1518-04-04 00:01] falls asleep
#
# {'month': 4, 'day': 4, 'offset': 1, 'action': 'sleep'}
# Starting sleep at minute 1
# [1518-04-04 00:29] wakes up
#
# {'month': 4, 'day': 4, 'offset': 29, 'action': 'wake'}
# Updating counter between 1 and 29
# [1518-04-04 00:45] falls asleep
#
# {'month': 4, 'day': 4, 'offset': 45, 'action': 'sleep'}
# Starting sleep at minute 45
# [1518-04-04 00:51] wakes up
#
# {'month': 4, 'day': 4, 'offset': 51, 'action': 'wake'}
# Updating counter between 45 and 51
# [1518-04-04 23:59] Guard #2399 begins shift
#
# {'month': 4, 'day': 5, 'offset': -1, 'action': '#2399'}
# Changing guard to #2399
# [1518-04-05 00:52] falls asleep
#
# {'month': 4, 'day': 5, 'offset': 52, 'action': 'sleep'}
# Starting sleep at minute 52
# [1518-04-05 00:57] wakes up
#
# {'month': 4, 'day': 5, 'offset': 57, 'action': 'wake'}
# Updating counter between 52 and 57
# [1518-04-05 23:59] Guard #1091 begins shift
#
# {'month': 4, 'day': 6, 'offset': -1, 'action': '#1091'}
# Changing guard to #1091
# [1518-04-06 00:24] falls asleep
#
# {'month': 4, 'day': 6, 'offset': 24, 'action': 'sleep'}
# Starting sleep at minute 24
# [1518-04-06 00:51] wakes up
#
# {'month': 4, 'day': 6, 'offset': 51, 'action': 'wake'}
# Updating counter between 24 and 51
# [1518-04-06 00:56] falls asleep
#
# {'month': 4, 'day': 6, 'offset': 56, 'action': 'sleep'}
# Starting sleep at minute 56
# [1518-04-06 00:58] wakes up
#
# {'month': 4, 'day': 6, 'offset': 58, 'action': 'wake'}
# Updating counter between 56 and 58
# [1518-04-06 23:58] Guard #2399 begins shift
#
# {'month': 4, 'day': 7, 'offset': -2, 'action': '#2399'}
# Changing guard to #2399
# [1518-04-07 00:21] falls asleep
#
# {'month': 4, 'day': 7, 'offset': 21, 'action': 'sleep'}
# Starting sleep at minute 21
# [1518-04-07 00:48] wakes up
#
# {'month': 4, 'day': 7, 'offset': 48, 'action': 'wake'}
# Updating counter between 21 and 48
# [1518-04-08 00:02] Guard #1051 begins shift
#
# {'month': 4, 'day': 8, 'offset': 2, 'action': '#1051'}
# Changing guard to #1051
# [1518-04-08 00:18] falls asleep
#
# {'month': 4, 'day': 8, 'offset': 18, 'action': 'sleep'}
# Starting sleep at minute 18
# [1518-04-08 00:35] wakes up
#
# {'month': 4, 'day': 8, 'offset': 35, 'action': 'wake'}
# Updating counter between 18 and 35
# [1518-04-08 00:42] falls asleep
#
# {'month': 4, 'day': 8, 'offset': 42, 'action': 'sleep'}
# Starting sleep at minute 42
# [1518-04-08 00:49] wakes up
#
# {'month': 4, 'day': 8, 'offset': 49, 'action': 'wake'}
# Updating counter between 42 and 49
# [1518-04-08 00:54] falls asleep
#
# {'month': 4, 'day': 8, 'offset': 54, 'action': 'sleep'}
# Starting sleep at minute 54
# [1518-04-08 00:57] wakes up
#
# {'month': 4, 'day': 8, 'offset': 57, 'action': 'wake'}
# Updating counter between 54 and 57
# [1518-04-08 23:57] Guard #269 begins shift
#
# {'month': 4, 'day': 9, 'offset': -3, 'action': '#269'}
# Changing guard to #269
# [1518-04-09 00:45] falls asleep
#
# {'month': 4, 'day': 9, 'offset': 45, 'action': 'sleep'}
# Starting sleep at minute 45
# [1518-04-09 00:55] wakes up
#
# {'month': 4, 'day': 9, 'offset': 55, 'action': 'wake'}
# Updating counter between 45 and 55
# [1518-04-09 23:59] Guard #2267 begins shift
#
# {'month': 4, 'day': 10, 'offset': -1, 'action': '#2267'}
# Changing guard to #2267
# [1518-04-10 00:30] falls asleep
#
# {'month': 4, 'day': 10, 'offset': 30, 'action': 'sleep'}
# Starting sleep at minute 30
# [1518-04-10 00:57] wakes up
#
# {'month': 4, 'day': 10, 'offset': 57, 'action': 'wake'}
# Updating counter between 30 and 57
# [1518-04-11 00:00] Guard #2333 begins shift
#
# {'month': 4, 'day': 11, 'offset': 0, 'action': '#2333'}
# Changing guard to #2333
# [1518-04-11 00:33] falls asleep
#
# {'month': 4, 'day': 11, 'offset': 33, 'action': 'sleep'}
# Starting sleep at minute 33
# [1518-04-11 00:34] wakes up
#
# {'month': 4, 'day': 11, 'offset': 34, 'action': 'wake'}
# Updating counter between 33 and 34
# [1518-04-11 00:37] falls asleep
#
# {'month': 4, 'day': 11, 'offset': 37, 'action': 'sleep'}
# Starting sleep at minute 37
# [1518-04-11 00:48] wakes up
#
# {'month': 4, 'day': 11, 'offset': 48, 'action': 'wake'}
# Updating counter between 37 and 48
# [1518-04-11 00:54] falls asleep
#
# {'month': 4, 'day': 11, 'offset': 54, 'action': 'sleep'}
# Starting sleep at minute 54
# [1518-04-11 00:57] wakes up
#
# {'month': 4, 'day': 11, 'offset': 57, 'action': 'wake'}
# Updating counter between 54 and 57
# [1518-04-11 23:58] Guard #509 begins shift
#
# {'month': 4, 'day': 12, 'offset': -2, 'action': '#509'}
# Changing guard to #509
# [1518-04-12 00:15] falls asleep
#
# {'month': 4, 'day': 12, 'offset': 15, 'action': 'sleep'}
# Starting sleep at minute 15
# [1518-04-12 00:20] wakes up
#
# {'month': 4, 'day': 12, 'offset': 20, 'action': 'wake'}
# Updating counter between 15 and 20
# [1518-04-12 00:48] falls asleep
#
# {'month': 4, 'day': 12, 'offset': 48, 'action': 'sleep'}
# Starting sleep at minute 48
# [1518-04-12 00:51] wakes up
#
# {'month': 4, 'day': 12, 'offset': 51, 'action': 'wake'}
# Updating counter between 48 and 51
# [1518-04-12 23:57] Guard #1091 begins shift
#
# {'month': 4, 'day': 13, 'offset': -3, 'action': '#1091'}
# Changing guard to #1091
# [1518-04-13 00:08] falls asleep
#
# {'month': 4, 'day': 13, 'offset': 8, 'action': 'sleep'}
# Starting sleep at minute 8
# [1518-04-13 00:38] wakes up
#
# {'month': 4, 'day': 13, 'offset': 38, 'action': 'wake'}
# Updating counter between 8 and 38
# [1518-04-13 00:44] falls asleep
#
# {'month': 4, 'day': 13, 'offset': 44, 'action': 'sleep'}
# Starting sleep at minute 44
# [1518-04-13 00:56] wakes up
#
# {'month': 4, 'day': 13, 'offset': 56, 'action': 'wake'}
# Updating counter between 44 and 56
# [1518-04-14 00:03] Guard #3203 begins shift
#
# {'month': 4, 'day': 14, 'offset': 3, 'action': '#3203'}
# Changing guard to #3203
# [1518-04-14 00:15] falls asleep
#
# {'month': 4, 'day': 14, 'offset': 15, 'action': 'sleep'}
# Starting sleep at minute 15
# [1518-04-14 00:48] wakes up
#
# {'month': 4, 'day': 14, 'offset': 48, 'action': 'wake'}
# Updating counter between 15 and 48
# [1518-04-14 00:51] falls asleep
#
# {'month': 4, 'day': 14, 'offset': 51, 'action': 'sleep'}
# Starting sleep at minute 51
# [1518-04-14 00:59] wakes up
#
# {'month': 4, 'day': 14, 'offset': 59, 'action': 'wake'}
# Updating counter between 51 and 59
# [1518-04-14 23:58] Guard #2851 begins shift
#
# {'month': 4, 'day': 15, 'offset': -2, 'action': '#2851'}
# Changing guard to #2851
# [1518-04-15 00:21] falls asleep
#
# {'month': 4, 'day': 15, 'offset': 21, 'action': 'sleep'}
# Starting sleep at minute 21
# [1518-04-15 00:29] wakes up
#
# {'month': 4, 'day': 15, 'offset': 29, 'action': 'wake'}
# Updating counter between 21 and 29
# [1518-04-15 00:35] falls asleep
#
# {'month': 4, 'day': 15, 'offset': 35, 'action': 'sleep'}
# Starting sleep at minute 35
# [1518-04-15 00:46] wakes up
#
# {'month': 4, 'day': 15, 'offset': 46, 'action': 'wake'}
# Updating counter between 35 and 46
# [1518-04-15 23:56] Guard #2267 begins shift
#
# {'month': 4, 'day': 16, 'offset': -4, 'action': '#2267'}
# Changing guard to #2267
# [1518-04-16 00:07] falls asleep
#
# {'month': 4, 'day': 16, 'offset': 7, 'action': 'sleep'}
# Starting sleep at minute 7
# [1518-04-16 00:39] wakes up
#
# {'month': 4, 'day': 16, 'offset': 39, 'action': 'wake'}
# Updating counter between 7 and 39
# [1518-04-16 23:54] Guard #2267 begins shift
#
# {'month': 4, 'day': 17, 'offset': -6, 'action': '#2267'}
# Changing guard to #2267
# [1518-04-17 00:04] falls asleep
#
# {'month': 4, 'day': 17, 'offset': 4, 'action': 'sleep'}
# Starting sleep at minute 4
# [1518-04-17 00:54] wakes up
#
# {'month': 4, 'day': 17, 'offset': 54, 'action': 'wake'}
# Updating counter between 4 and 54
# [1518-04-17 00:57] falls asleep
#
# {'month': 4, 'day': 17, 'offset': 57, 'action': 'sleep'}
# Starting sleep at minute 57
# [1518-04-17 00:59] wakes up
#
# {'month': 4, 'day': 17, 'offset': 59, 'action': 'wake'}
# Updating counter between 57 and 59
# [1518-04-17 23:59] Guard #1307 begins shift
#
# {'month': 4, 'day': 18, 'offset': -1, 'action': '#1307'}
# Changing guard to #1307
# [1518-04-18 00:16] falls asleep
#
# {'month': 4, 'day': 18, 'offset': 16, 'action': 'sleep'}
# Starting sleep at minute 16
# [1518-04-18 00:57] wakes up
#
# {'month': 4, 'day': 18, 'offset': 57, 'action': 'wake'}
# Updating counter between 16 and 57
# [1518-04-18 23:57] Guard #1051 begins shift
#
# {'month': 4, 'day': 19, 'offset': -3, 'action': '#1051'}
# Changing guard to #1051
# [1518-04-19 00:08] falls asleep
#
# {'month': 4, 'day': 19, 'offset': 8, 'action': 'sleep'}
# Starting sleep at minute 8
# [1518-04-19 00:18] wakes up
#
# {'month': 4, 'day': 19, 'offset': 18, 'action': 'wake'}
# Updating counter between 8 and 18
# [1518-04-20 00:00] Guard #2447 begins shift
#
# {'month': 4, 'day': 20, 'offset': 0, 'action': '#2447'}
# Changing guard to #2447
# [1518-04-20 00:15] falls asleep
#
# {'month': 4, 'day': 20, 'offset': 15, 'action': 'sleep'}
# Starting sleep at minute 15
# [1518-04-20 00:52] wakes up
#
# {'month': 4, 'day': 20, 'offset': 52, 'action': 'wake'}
# Updating counter between 15 and 52
# [1518-04-20 23:47] Guard #1601 begins shift
#
# {'month': 4, 'day': 21, 'offset': -13, 'action': '#1601'}
# Changing guard to #1601
# [1518-04-21 00:01] falls asleep
#
# {'month': 4, 'day': 21, 'offset': 1, 'action': 'sleep'}
# Starting sleep at minute 1
# [1518-04-21 00:11] wakes up
#
# {'month': 4, 'day': 21, 'offset': 11, 'action': 'wake'}
# Updating counter between 1 and 11
# [1518-04-21 00:20] falls asleep
#
# {'month': 4, 'day': 21, 'offset': 20, 'action': 'sleep'}
# Starting sleep at minute 20
# [1518-04-21 00:57] wakes up
#
# {'month': 4, 'day': 21, 'offset': 57, 'action': 'wake'}
# Updating counter between 20 and 57
# [1518-04-21 23:58] Guard #2851 begins shift
#
# {'month': 4, 'day': 22, 'offset': -2, 'action': '#2851'}
# Changing guard to #2851
# [1518-04-22 00:10] falls asleep
#
# {'month': 4, 'day': 22, 'offset': 10, 'action': 'sleep'}
# Starting sleep at minute 10
# [1518-04-22 00:25] wakes up
#
# {'month': 4, 'day': 22, 'offset': 25, 'action': 'wake'}
# Updating counter between 10 and 25
# [1518-04-22 23:58] Guard #2153 begins shift
#
# {'month': 4, 'day': 23, 'offset': -2, 'action': '#2153'}
# Changing guard to #2153
# [1518-04-23 00:10] falls asleep
#
# {'month': 4, 'day': 23, 'offset': 10, 'action': 'sleep'}
# Starting sleep at minute 10
# [1518-04-23 00:27] wakes up
#
# {'month': 4, 'day': 23, 'offset': 27, 'action': 'wake'}
# Updating counter between 10 and 27
# [1518-04-23 00:37] falls asleep
#
# {'month': 4, 'day': 23, 'offset': 37, 'action': 'sleep'}
# Starting sleep at minute 37
# [1518-04-23 00:38] wakes up
#
# {'month': 4, 'day': 23, 'offset': 38, 'action': 'wake'}
# Updating counter between 37 and 38
# [1518-04-23 00:47] falls asleep
#
# {'month': 4, 'day': 23, 'offset': 47, 'action': 'sleep'}
# Starting sleep at minute 47
# [1518-04-23 00:59] wakes up
#
# {'month': 4, 'day': 23, 'offset': 59, 'action': 'wake'}
# Updating counter between 47 and 59
# [1518-04-24 00:00] Guard #3559 begins shift
#
# {'month': 4, 'day': 24, 'offset': 0, 'action': '#3559'}
# Changing guard to #3559
# [1518-04-24 00:47] falls asleep
#
# {'month': 4, 'day': 24, 'offset': 47, 'action': 'sleep'}
# Starting sleep at minute 47
# [1518-04-24 00:48] wakes up
#
# {'month': 4, 'day': 24, 'offset': 48, 'action': 'wake'}
# Updating counter between 47 and 48
# [1518-04-25 00:03] Guard #269 begins shift
#
# {'month': 4, 'day': 25, 'offset': 3, 'action': '#269'}
# Changing guard to #269
# [1518-04-25 00:15] falls asleep
#
# {'month': 4, 'day': 25, 'offset': 15, 'action': 'sleep'}
# Starting sleep at minute 15
# [1518-04-25 00:55] wakes up
#
# {'month': 4, 'day': 25, 'offset': 55, 'action': 'wake'}
# Updating counter between 15 and 55
# [1518-04-25 23:59] Guard #3203 begins shift
#
# {'month': 4, 'day': 26, 'offset': -1, 'action': '#3203'}
# Changing guard to #3203
# [1518-04-26 00:24] falls asleep
#
# {'month': 4, 'day': 26, 'offset': 24, 'action': 'sleep'}
# Starting sleep at minute 24
# [1518-04-26 00:31] wakes up
#
# {'month': 4, 'day': 26, 'offset': 31, 'action': 'wake'}
# Updating counter between 24 and 31
# [1518-04-27 00:03] Guard #2267 begins shift
#
# {'month': 4, 'day': 27, 'offset': 3, 'action': '#2267'}
# Changing guard to #2267
# [1518-04-27 00:14] falls asleep
#
# {'month': 4, 'day': 27, 'offset': 14, 'action': 'sleep'}
# Starting sleep at minute 14
# [1518-04-27 00:51] wakes up
#
# {'month': 4, 'day': 27, 'offset': 51, 'action': 'wake'}
# Updating counter between 14 and 51
# [1518-04-28 00:00] Guard #269 begins shift
#
# {'month': 4, 'day': 28, 'offset': 0, 'action': '#269'}
# Changing guard to #269
# [1518-04-28 00:45] falls asleep
#
# {'month': 4, 'day': 28, 'offset': 45, 'action': 'sleep'}
# Starting sleep at minute 45
# [1518-04-28 00:57] wakes up
#
# {'month': 4, 'day': 28, 'offset': 57, 'action': 'wake'}
# Updating counter between 45 and 57
# [1518-04-29 00:00] Guard #1601 begins shift
#
# {'month': 4, 'day': 29, 'offset': 0, 'action': '#1601'}
# Changing guard to #1601
# [1518-04-29 00:38] falls asleep
#
# {'month': 4, 'day': 29, 'offset': 38, 'action': 'sleep'}
# Starting sleep at minute 38
# [1518-04-29 00:48] wakes up
#
# {'month': 4, 'day': 29, 'offset': 48, 'action': 'wake'}
# Updating counter between 38 and 48
# [1518-04-29 23:56] Guard #349 begins shift
#
# {'month': 4, 'day': 30, 'offset': -4, 'action': '#349'}
# Changing guard to #349
# [1518-04-30 00:17] falls asleep
#
# {'month': 4, 'day': 30, 'offset': 17, 'action': 'sleep'}
# Starting sleep at minute 17
# [1518-04-30 00:28] wakes up
#
# {'month': 4, 'day': 30, 'offset': 28, 'action': 'wake'}
# Updating counter between 17 and 28
# [1518-05-01 00:03] Guard #1091 begins shift
#
# {'month': 5, 'day': 1, 'offset': 3, 'action': '#1091'}
# Changing guard to #1091
# [1518-05-01 00:09] falls asleep
#
# {'month': 5, 'day': 1, 'offset': 9, 'action': 'sleep'}
# Starting sleep at minute 9
# [1518-05-01 00:30] wakes up
#
# {'month': 5, 'day': 1, 'offset': 30, 'action': 'wake'}
# Updating counter between 9 and 30
# [1518-05-01 23:46] Guard #1601 begins shift
#
# {'month': 5, 'day': 2, 'offset': -14, 'action': '#1601'}
# Changing guard to #1601
# [1518-05-02 00:00] falls asleep
#
# {'month': 5, 'day': 2, 'offset': 0, 'action': 'sleep'}
# Starting sleep at minute 0
# [1518-05-02 00:35] wakes up
#
# {'month': 5, 'day': 2, 'offset': 35, 'action': 'wake'}
# Updating counter between 0 and 35
# [1518-05-02 00:39] falls asleep
#
# {'month': 5, 'day': 2, 'offset': 39, 'action': 'sleep'}
# Starting sleep at minute 39
# [1518-05-02 00:54] wakes up
#
# {'month': 5, 'day': 2, 'offset': 54, 'action': 'wake'}
# Updating counter between 39 and 54
# [1518-05-03 00:02] Guard #2153 begins shift
#
# {'month': 5, 'day': 3, 'offset': 2, 'action': '#2153'}
# Changing guard to #2153
# [1518-05-03 00:20] falls asleep
#
# {'month': 5, 'day': 3, 'offset': 20, 'action': 'sleep'}
# Starting sleep at minute 20
# [1518-05-03 00:34] wakes up
#
# {'month': 5, 'day': 3, 'offset': 34, 'action': 'wake'}
# Updating counter between 20 and 34
# [1518-05-03 00:47] falls asleep
#
# {'month': 5, 'day': 3, 'offset': 47, 'action': 'sleep'}
# Starting sleep at minute 47
# [1518-05-03 00:49] wakes up
#
# {'month': 5, 'day': 3, 'offset': 49, 'action': 'wake'}
# Updating counter between 47 and 49
# [1518-05-03 23:58] Guard #1117 begins shift
#
# {'month': 5, 'day': 4, 'offset': -2, 'action': '#1117'}
# Changing guard to #1117
# [1518-05-04 00:45] falls asleep
#
# {'month': 5, 'day': 4, 'offset': 45, 'action': 'sleep'}
# Starting sleep at minute 45
# [1518-05-04 00:46] wakes up
#
# {'month': 5, 'day': 4, 'offset': 46, 'action': 'wake'}
# Updating counter between 45 and 46
# [1518-05-04 23:50] Guard #163 begins shift
#
# {'month': 5, 'day': 5, 'offset': -10, 'action': '#163'}
# Changing guard to #163
# [1518-05-05 00:02] falls asleep
#
# {'month': 5, 'day': 5, 'offset': 2, 'action': 'sleep'}
# Starting sleep at minute 2
# [1518-05-05 00:07] wakes up
#
# {'month': 5, 'day': 5, 'offset': 7, 'action': 'wake'}
# Updating counter between 2 and 7
# [1518-05-05 00:10] falls asleep
#
# {'month': 5, 'day': 5, 'offset': 10, 'action': 'sleep'}
# Starting sleep at minute 10
# [1518-05-05 00:28] wakes up
#
# {'month': 5, 'day': 5, 'offset': 28, 'action': 'wake'}
# Updating counter between 10 and 28
# [1518-05-05 23:58] Guard #3203 begins shift
#
# {'month': 5, 'day': 6, 'offset': -2, 'action': '#3203'}
# Changing guard to #3203
# [1518-05-06 00:08] falls asleep
#
# {'month': 5, 'day': 6, 'offset': 8, 'action': 'sleep'}
# Starting sleep at minute 8
# [1518-05-06 00:27] wakes up
#
# {'month': 5, 'day': 6, 'offset': 27, 'action': 'wake'}
# Updating counter between 8 and 27
# [1518-05-07 00:01] Guard #163 begins shift
#
# {'month': 5, 'day': 7, 'offset': 1, 'action': '#163'}
# Changing guard to #163
# [1518-05-07 00:22] falls asleep
#
# {'month': 5, 'day': 7, 'offset': 22, 'action': 'sleep'}
# Starting sleep at minute 22
# [1518-05-07 00:54] wakes up
#
# {'month': 5, 'day': 7, 'offset': 54, 'action': 'wake'}
# Updating counter between 22 and 54
# [1518-05-08 00:02] Guard #163 begins shift
#
# {'month': 5, 'day': 8, 'offset': 2, 'action': '#163'}
# Changing guard to #163
# [1518-05-08 00:27] falls asleep
#
# {'month': 5, 'day': 8, 'offset': 27, 'action': 'sleep'}
# Starting sleep at minute 27
# [1518-05-08 00:32] wakes up
#
# {'month': 5, 'day': 8, 'offset': 32, 'action': 'wake'}
# Updating counter between 27 and 32
# [1518-05-08 00:49] falls asleep
#
# {'month': 5, 'day': 8, 'offset': 49, 'action': 'sleep'}
# Starting sleep at minute 49
# [1518-05-08 00:56] wakes up
#
# {'month': 5, 'day': 8, 'offset': 56, 'action': 'wake'}
# Updating counter between 49 and 56
# [1518-05-09 00:00] Guard #1051 begins shift
#
# {'month': 5, 'day': 9, 'offset': 0, 'action': '#1051'}
# Changing guard to #1051
# [1518-05-09 00:56] falls asleep
#
# {'month': 5, 'day': 9, 'offset': 56, 'action': 'sleep'}
# Starting sleep at minute 56
# [1518-05-09 00:59] wakes up
#
# {'month': 5, 'day': 9, 'offset': 59, 'action': 'wake'}
# Updating counter between 56 and 59
# [1518-05-10 00:00] Guard #2153 begins shift
#
# {'month': 5, 'day': 10, 'offset': 0, 'action': '#2153'}
# Changing guard to #2153
# [1518-05-10 00:06] falls asleep
#
# {'month': 5, 'day': 10, 'offset': 6, 'action': 'sleep'}
# Starting sleep at minute 6
# [1518-05-10 00:38] wakes up
#
# {'month': 5, 'day': 10, 'offset': 38, 'action': 'wake'}
# Updating counter between 6 and 38
# [1518-05-10 00:50] falls asleep
#
# {'month': 5, 'day': 10, 'offset': 50, 'action': 'sleep'}
# Starting sleep at minute 50
# [1518-05-10 00:55] wakes up
#
# {'month': 5, 'day': 10, 'offset': 55, 'action': 'wake'}
# Updating counter between 50 and 55
# [1518-05-11 00:02] Guard #353 begins shift
#
# {'month': 5, 'day': 11, 'offset': 2, 'action': '#353'}
# Changing guard to #353
# [1518-05-11 00:22] falls asleep
#
# {'month': 5, 'day': 11, 'offset': 22, 'action': 'sleep'}
# Starting sleep at minute 22
# [1518-05-11 00:51] wakes up
#
# {'month': 5, 'day': 11, 'offset': 51, 'action': 'wake'}
# Updating counter between 22 and 51
# [1518-05-11 23:56] Guard #1601 begins shift
#
# {'month': 5, 'day': 12, 'offset': -4, 'action': '#1601'}
# Changing guard to #1601
# [1518-05-12 00:08] falls asleep
#
# {'month': 5, 'day': 12, 'offset': 8, 'action': 'sleep'}
# Starting sleep at minute 8
# [1518-05-12 00:21] wakes up
#
# {'month': 5, 'day': 12, 'offset': 21, 'action': 'wake'}
# Updating counter between 8 and 21
# [1518-05-12 00:40] falls asleep
#
# {'month': 5, 'day': 12, 'offset': 40, 'action': 'sleep'}
# Starting sleep at minute 40
# [1518-05-12 00:53] wakes up
#
# {'month': 5, 'day': 12, 'offset': 53, 'action': 'wake'}
# Updating counter between 40 and 53
# [1518-05-12 23:57] Guard #2267 begins shift
#
# {'month': 5, 'day': 13, 'offset': -3, 'action': '#2267'}
# Changing guard to #2267
# [1518-05-13 00:17] falls asleep
#
# {'month': 5, 'day': 13, 'offset': 17, 'action': 'sleep'}
# Starting sleep at minute 17
# [1518-05-13 00:51] wakes up
#
# {'month': 5, 'day': 13, 'offset': 51, 'action': 'wake'}
# Updating counter between 17 and 51
# [1518-05-14 00:02] Guard #1601 begins shift
#
# {'month': 5, 'day': 14, 'offset': 2, 'action': '#1601'}
# Changing guard to #1601
# [1518-05-14 00:26] falls asleep
#
# {'month': 5, 'day': 14, 'offset': 26, 'action': 'sleep'}
# Starting sleep at minute 26
# [1518-05-14 00:59] wakes up
#
# {'month': 5, 'day': 14, 'offset': 59, 'action': 'wake'}
# Updating counter between 26 and 59
# [1518-05-14 23:59] Guard #1117 begins shift
#
# {'month': 5, 'day': 15, 'offset': -1, 'action': '#1117'}
# Changing guard to #1117
# [1518-05-15 00:06] falls asleep
#
# {'month': 5, 'day': 15, 'offset': 6, 'action': 'sleep'}
# Starting sleep at minute 6
# [1518-05-15 00:31] wakes up
#
# {'month': 5, 'day': 15, 'offset': 31, 'action': 'wake'}
# Updating counter between 6 and 31
# [1518-05-15 00:45] falls asleep
#
# {'month': 5, 'day': 15, 'offset': 45, 'action': 'sleep'}
# Starting sleep at minute 45
# [1518-05-15 00:54] wakes up
#
# {'month': 5, 'day': 15, 'offset': 54, 'action': 'wake'}
# Updating counter between 45 and 54
# [1518-05-15 23:47] Guard #3203 begins shift
#
# {'month': 5, 'day': 16, 'offset': -13, 'action': '#3203'}
# Changing guard to #3203
# [1518-05-16 00:05] falls asleep
#
# {'month': 5, 'day': 16, 'offset': 5, 'action': 'sleep'}
# Starting sleep at minute 5
# [1518-05-16 00:28] wakes up
#
# {'month': 5, 'day': 16, 'offset': 28, 'action': 'wake'}
# Updating counter between 5 and 28
# [1518-05-16 00:32] falls asleep
#
# {'month': 5, 'day': 16, 'offset': 32, 'action': 'sleep'}
# Starting sleep at minute 32
# [1518-05-16 00:45] wakes up
#
# {'month': 5, 'day': 16, 'offset': 45, 'action': 'wake'}
# Updating counter between 32 and 45
# [1518-05-17 00:04] Guard #1601 begins shift
#
# {'month': 5, 'day': 17, 'offset': 4, 'action': '#1601'}
# Changing guard to #1601
# [1518-05-17 00:19] falls asleep
#
# {'month': 5, 'day': 17, 'offset': 19, 'action': 'sleep'}
# Starting sleep at minute 19
# [1518-05-17 00:39] wakes up
#
# {'month': 5, 'day': 17, 'offset': 39, 'action': 'wake'}
# Updating counter between 19 and 39
# [1518-05-18 00:02] Guard #2399 begins shift
#
# {'month': 5, 'day': 18, 'offset': 2, 'action': '#2399'}
# Changing guard to #2399
# [1518-05-18 00:17] falls asleep
#
# {'month': 5, 'day': 18, 'offset': 17, 'action': 'sleep'}
# Starting sleep at minute 17
# [1518-05-18 00:55] wakes up
#
# {'month': 5, 'day': 18, 'offset': 55, 'action': 'wake'}
# Updating counter between 17 and 55
# [1518-05-18 23:56] Guard #163 begins shift
#
# {'month': 5, 'day': 19, 'offset': -4, 'action': '#163'}
# Changing guard to #163
# [1518-05-19 00:26] falls asleep
#
# {'month': 5, 'day': 19, 'offset': 26, 'action': 'sleep'}
# Starting sleep at minute 26
# [1518-05-19 00:31] wakes up
#
# {'month': 5, 'day': 19, 'offset': 31, 'action': 'wake'}
# Updating counter between 26 and 31
# [1518-05-19 00:37] falls asleep
#
# {'month': 5, 'day': 19, 'offset': 37, 'action': 'sleep'}
# Starting sleep at minute 37
# [1518-05-19 00:44] wakes up
#
# {'month': 5, 'day': 19, 'offset': 44, 'action': 'wake'}
# Updating counter between 37 and 44
# [1518-05-19 00:48] falls asleep
#
# {'month': 5, 'day': 19, 'offset': 48, 'action': 'sleep'}
# Starting sleep at minute 48
# [1518-05-19 00:51] wakes up
#
# {'month': 5, 'day': 19, 'offset': 51, 'action': 'wake'}
# Updating counter between 48 and 51
# [1518-05-19 23:58] Guard #2851 begins shift
#
# {'month': 5, 'day': 20, 'offset': -2, 'action': '#2851'}
# Changing guard to #2851
# [1518-05-20 00:12] falls asleep
#
# {'month': 5, 'day': 20, 'offset': 12, 'action': 'sleep'}
# Starting sleep at minute 12
# [1518-05-20 00:32] wakes up
#
# {'month': 5, 'day': 20, 'offset': 32, 'action': 'wake'}
# Updating counter between 12 and 32
# [1518-05-20 00:39] falls asleep
#
# {'month': 5, 'day': 20, 'offset': 39, 'action': 'sleep'}
# Starting sleep at minute 39
# [1518-05-20 00:57] wakes up
#
# {'month': 5, 'day': 20, 'offset': 57, 'action': 'wake'}
# Updating counter between 39 and 57
# [1518-05-20 23:57] Guard #1601 begins shift
#
# {'month': 5, 'day': 21, 'offset': -3, 'action': '#1601'}
# Changing guard to #1601
# [1518-05-21 00:06] falls asleep
#
# {'month': 5, 'day': 21, 'offset': 6, 'action': 'sleep'}
# Starting sleep at minute 6
# [1518-05-21 00:08] wakes up
#
# {'month': 5, 'day': 21, 'offset': 8, 'action': 'wake'}
# Updating counter between 6 and 8
# [1518-05-21 00:23] falls asleep
#
# {'month': 5, 'day': 21, 'offset': 23, 'action': 'sleep'}
# Starting sleep at minute 23
# [1518-05-21 00:49] wakes up
#
# {'month': 5, 'day': 21, 'offset': 49, 'action': 'wake'}
# Updating counter between 23 and 49
# [1518-05-21 00:55] falls asleep
#
# {'month': 5, 'day': 21, 'offset': 55, 'action': 'sleep'}
# Starting sleep at minute 55
# [1518-05-21 00:57] wakes up
#
# {'month': 5, 'day': 21, 'offset': 57, 'action': 'wake'}
# Updating counter between 55 and 57
# [1518-05-21 23:58] Guard #2153 begins shift
#
# {'month': 5, 'day': 22, 'offset': -2, 'action': '#2153'}
# Changing guard to #2153
# [1518-05-22 00:22] falls asleep
#
# {'month': 5, 'day': 22, 'offset': 22, 'action': 'sleep'}
# Starting sleep at minute 22
# [1518-05-22 00:23] wakes up
#
# {'month': 5, 'day': 22, 'offset': 23, 'action': 'wake'}
# Updating counter between 22 and 23
# [1518-05-22 00:33] falls asleep
#
# {'month': 5, 'day': 22, 'offset': 33, 'action': 'sleep'}
# Starting sleep at minute 33
# [1518-05-22 00:55] wakes up
#
# {'month': 5, 'day': 22, 'offset': 55, 'action': 'wake'}
# Updating counter between 33 and 55
# [1518-05-22 23:59] Guard #2267 begins shift
#
# {'month': 5, 'day': 23, 'offset': -1, 'action': '#2267'}
# Changing guard to #2267
# [1518-05-23 00:21] falls asleep
#
# {'month': 5, 'day': 23, 'offset': 21, 'action': 'sleep'}
# Starting sleep at minute 21
# [1518-05-23 00:53] wakes up
#
# {'month': 5, 'day': 23, 'offset': 53, 'action': 'wake'}
# Updating counter between 21 and 53
# [1518-05-23 00:57] falls asleep
#
# {'month': 5, 'day': 23, 'offset': 57, 'action': 'sleep'}
# Starting sleep at minute 57
# [1518-05-23 00:58] wakes up
#
# {'month': 5, 'day': 23, 'offset': 58, 'action': 'wake'}
# Updating counter between 57 and 58
# [1518-05-23 23:46] Guard #691 begins shift
#
# {'month': 5, 'day': 24, 'offset': -14, 'action': '#691'}
# Changing guard to #691
# [1518-05-24 00:05] falls asleep
#
# {'month': 5, 'day': 24, 'offset': 5, 'action': 'sleep'}
# Starting sleep at minute 5
# [1518-05-24 00:07] wakes up
#
# {'month': 5, 'day': 24, 'offset': 7, 'action': 'wake'}
# Updating counter between 5 and 7
# [1518-05-24 00:27] falls asleep
#
# {'month': 5, 'day': 24, 'offset': 27, 'action': 'sleep'}
# Starting sleep at minute 27
# [1518-05-24 00:54] wakes up
#
# {'month': 5, 'day': 24, 'offset': 54, 'action': 'wake'}
# Updating counter between 27 and 54
# [1518-05-24 23:56] Guard #163 begins shift
#
# {'month': 5, 'day': 25, 'offset': -4, 'action': '#163'}
# Changing guard to #163
# [1518-05-25 00:28] falls asleep
#
# {'month': 5, 'day': 25, 'offset': 28, 'action': 'sleep'}
# Starting sleep at minute 28
# [1518-05-25 00:32] wakes up
#
# {'month': 5, 'day': 25, 'offset': 32, 'action': 'wake'}
# Updating counter between 28 and 32
# [1518-05-25 23:59] Guard #1307 begins shift
#
# {'month': 5, 'day': 26, 'offset': -1, 'action': '#1307'}
# Changing guard to #1307
# [1518-05-26 00:28] falls asleep
#
# {'month': 5, 'day': 26, 'offset': 28, 'action': 'sleep'}
# Starting sleep at minute 28
# [1518-05-26 00:35] wakes up
#
# {'month': 5, 'day': 26, 'offset': 35, 'action': 'wake'}
# Updating counter between 28 and 35
# [1518-05-26 00:41] falls asleep
#
# {'month': 5, 'day': 26, 'offset': 41, 'action': 'sleep'}
# Starting sleep at minute 41
# [1518-05-26 00:43] wakes up
#
# {'month': 5, 'day': 26, 'offset': 43, 'action': 'wake'}
# Updating counter between 41 and 43
# [1518-05-26 00:51] falls asleep
#
# {'month': 5, 'day': 26, 'offset': 51, 'action': 'sleep'}
# Starting sleep at minute 51
# [1518-05-26 00:53] wakes up
#
# {'month': 5, 'day': 26, 'offset': 53, 'action': 'wake'}
# Updating counter between 51 and 53
# [1518-05-27 00:00] Guard #269 begins shift
#
# {'month': 5, 'day': 27, 'offset': 0, 'action': '#269'}
# Changing guard to #269
# [1518-05-27 00:10] falls asleep
#
# {'month': 5, 'day': 27, 'offset': 10, 'action': 'sleep'}
# Starting sleep at minute 10
# [1518-05-27 00:15] wakes up
#
# {'month': 5, 'day': 27, 'offset': 15, 'action': 'wake'}
# Updating counter between 10 and 15
# [1518-05-28 00:04] Guard #691 begins shift
#
# {'month': 5, 'day': 28, 'offset': 4, 'action': '#691'}
# Changing guard to #691
# [1518-05-28 00:17] falls asleep
#
# {'month': 5, 'day': 28, 'offset': 17, 'action': 'sleep'}
# Starting sleep at minute 17
# [1518-05-28 00:38] wakes up
#
# {'month': 5, 'day': 28, 'offset': 38, 'action': 'wake'}
# Updating counter between 17 and 38
# [1518-05-28 00:43] falls asleep
#
# {'month': 5, 'day': 28, 'offset': 43, 'action': 'sleep'}
# Starting sleep at minute 43
# [1518-05-28 00:58] wakes up
#
# {'month': 5, 'day': 28, 'offset': 58, 'action': 'wake'}
# Updating counter between 43 and 58
# [1518-05-29 00:00] Guard #1051 begins shift
#
# {'month': 5, 'day': 29, 'offset': 0, 'action': '#1051'}
# Changing guard to #1051
# [1518-05-29 00:30] falls asleep
#
# {'month': 5, 'day': 29, 'offset': 30, 'action': 'sleep'}
# Starting sleep at minute 30
# [1518-05-29 00:57] wakes up
#
# {'month': 5, 'day': 29, 'offset': 57, 'action': 'wake'}
# Updating counter between 30 and 57
# [1518-05-29 23:59] Guard #2333 begins shift
#
# {'month': 5, 'day': 30, 'offset': -1, 'action': '#2333'}
# Changing guard to #2333
# [1518-05-30 00:37] falls asleep
#
# {'month': 5, 'day': 30, 'offset': 37, 'action': 'sleep'}
# Starting sleep at minute 37
# [1518-05-30 00:57] wakes up
#
# {'month': 5, 'day': 30, 'offset': 57, 'action': 'wake'}
# Updating counter between 37 and 57
# [1518-05-30 23:56] Guard #1307 begins shift
#
# {'month': 5, 'day': 31, 'offset': -4, 'action': '#1307'}
# Changing guard to #1307
# [1518-05-31 00:26] falls asleep
#
# {'month': 5, 'day': 31, 'offset': 26, 'action': 'sleep'}
# Starting sleep at minute 26
# [1518-05-31 00:35] wakes up
#
# {'month': 5, 'day': 31, 'offset': 35, 'action': 'wake'}
# Updating counter between 26 and 35
# [1518-05-31 00:38] falls asleep
#
# {'month': 5, 'day': 31, 'offset': 38, 'action': 'sleep'}
# Starting sleep at minute 38
# [1518-05-31 00:43] wakes up
#
# {'month': 5, 'day': 31, 'offset': 43, 'action': 'wake'}
# Updating counter between 38 and 43
# [1518-05-31 00:54] falls asleep
#
# {'month': 5, 'day': 31, 'offset': 54, 'action': 'sleep'}
# Starting sleep at minute 54
# [1518-05-31 00:56] wakes up
#
# {'month': 5, 'day': 31, 'offset': 56, 'action': 'wake'}
# Updating counter between 54 and 56
# [1518-06-01 00:02] Guard #3559 begins shift
#
# {'month': 6, 'day': 1, 'offset': 2, 'action': '#3559'}
# Changing guard to #3559
# [1518-06-01 00:32] falls asleep
#
# {'month': 6, 'day': 1, 'offset': 32, 'action': 'sleep'}
# Starting sleep at minute 32
# [1518-06-01 00:34] wakes up
#
# {'month': 6, 'day': 1, 'offset': 34, 'action': 'wake'}
# Updating counter between 32 and 34
# [1518-06-01 00:41] falls asleep
#
# {'month': 6, 'day': 1, 'offset': 41, 'action': 'sleep'}
# Starting sleep at minute 41
# [1518-06-01 00:56] wakes up
#
# {'month': 6, 'day': 1, 'offset': 56, 'action': 'wake'}
# Updating counter between 41 and 56
# [1518-06-02 00:04] Guard #1307 begins shift
#
# {'month': 6, 'day': 2, 'offset': 4, 'action': '#1307'}
# Changing guard to #1307
# [1518-06-02 00:55] falls asleep
#
# {'month': 6, 'day': 2, 'offset': 55, 'action': 'sleep'}
# Starting sleep at minute 55
# [1518-06-02 00:57] wakes up
#
# {'month': 6, 'day': 2, 'offset': 57, 'action': 'wake'}
# Updating counter between 55 and 57
# [1518-06-02 23:57] Guard #2447 begins shift
#
# {'month': 6, 'day': 3, 'offset': -3, 'action': '#2447'}
# Changing guard to #2447
# [1518-06-03 00:21] falls asleep
#
# {'month': 6, 'day': 3, 'offset': 21, 'action': 'sleep'}
# Starting sleep at minute 21
# [1518-06-03 00:35] wakes up
#
# {'month': 6, 'day': 3, 'offset': 35, 'action': 'wake'}
# Updating counter between 21 and 35
# [1518-06-03 23:50] Guard #2399 begins shift
#
# {'month': 6, 'day': 4, 'offset': -10, 'action': '#2399'}
# Changing guard to #2399
# [1518-06-04 00:05] falls asleep
#
# {'month': 6, 'day': 4, 'offset': 5, 'action': 'sleep'}
# Starting sleep at minute 5
# [1518-06-04 00:13] wakes up
#
# {'month': 6, 'day': 4, 'offset': 13, 'action': 'wake'}
# Updating counter between 5 and 13
# [1518-06-04 00:43] falls asleep
#
# {'month': 6, 'day': 4, 'offset': 43, 'action': 'sleep'}
# Starting sleep at minute 43
# [1518-06-04 00:58] wakes up
#
# {'month': 6, 'day': 4, 'offset': 58, 'action': 'wake'}
# Updating counter between 43 and 58
# [1518-06-05 00:02] Guard #2333 begins shift
#
# {'month': 6, 'day': 5, 'offset': 2, 'action': '#2333'}
# Changing guard to #2333
# [1518-06-05 00:06] falls asleep
#
# {'month': 6, 'day': 5, 'offset': 6, 'action': 'sleep'}
# Starting sleep at minute 6
# [1518-06-05 00:54] wakes up
#
# {'month': 6, 'day': 5, 'offset': 54, 'action': 'wake'}
# Updating counter between 6 and 54
# [1518-06-06 00:00] Guard #2617 begins shift
#
# {'month': 6, 'day': 6, 'offset': 0, 'action': '#2617'}
# Changing guard to #2617
# [1518-06-06 00:26] falls asleep
#
# {'month': 6, 'day': 6, 'offset': 26, 'action': 'sleep'}
# Starting sleep at minute 26
# [1518-06-06 00:37] wakes up
#
# {'month': 6, 'day': 6, 'offset': 37, 'action': 'wake'}
# Updating counter between 26 and 37
# [1518-06-06 00:44] falls asleep
#
# {'month': 6, 'day': 6, 'offset': 44, 'action': 'sleep'}
# Starting sleep at minute 44
# [1518-06-06 00:56] wakes up
#
# {'month': 6, 'day': 6, 'offset': 56, 'action': 'wake'}
# Updating counter between 44 and 56
# [1518-06-07 00:04] Guard #1051 begins shift
#
# {'month': 6, 'day': 7, 'offset': 4, 'action': '#1051'}
# Changing guard to #1051
# [1518-06-07 00:13] falls asleep
#
# {'month': 6, 'day': 7, 'offset': 13, 'action': 'sleep'}
# Starting sleep at minute 13
# [1518-06-07 00:32] wakes up
#
# {'month': 6, 'day': 7, 'offset': 32, 'action': 'wake'}
# Updating counter between 13 and 32
# [1518-06-07 23:56] Guard #3559 begins shift
#
# ...
# [1518-10-21 00:58] wakes up
#
# {'month': 10, 'day': 21, 'offset': 58, 'action': 'wake'}
# Updating counter between 47 and 58
# [1518-10-22 00:00] Guard #1051 begins shift
#
# {'month': 10, 'day': 22, 'offset': 0, 'action': '#1051'}
# Changing guard to #1051
# [1518-10-22 00:24] falls asleep
#
# {'month': 10, 'day': 22, 'offset': 24, 'action': 'sleep'}
# Starting sleep at minute 24
# [1518-10-22 00:43] wakes up
#
# {'month': 10, 'day': 22, 'offset': 43, 'action': 'wake'}
# Updating counter between 24 and 43
# [1518-10-22 00:49] falls asleep
#
# {'month': 10, 'day': 22, 'offset': 49, 'action': 'sleep'}
# Starting sleep at minute 49
# [1518-10-22 00:58] wakes up
#
# {'month': 10, 'day': 22, 'offset': 58, 'action': 'wake'}
# Updating counter between 49 and 58
# [1518-10-22 23:59] Guard #3559 begins shift
#
# {'month': 10, 'day': 23, 'offset': -1, 'action': '#3559'}
# Changing guard to #3559
# [1518-10-23 00:24] falls asleep
#
# {'month': 10, 'day': 23, 'offset': 24, 'action': 'sleep'}
# Starting sleep at minute 24
# [1518-10-23 00:36] wakes up
#
# {'month': 10, 'day': 23, 'offset': 36, 'action': 'wake'}
# Updating counter between 24 and 36
# [1518-10-24 00:01] Guard #349 begins shift
#
# {'month': 10, 'day': 24, 'offset': 1, 'action': '#349'}
# Changing guard to #349
# [1518-10-24 00:15] falls asleep
#
# {'month': 10, 'day': 24, 'offset': 15, 'action': 'sleep'}
# Starting sleep at minute 15
# [1518-10-24 00:37] wakes up
#
# {'month': 10, 'day': 24, 'offset': 37, 'action': 'wake'}
# Updating counter between 15 and 37
# [1518-10-24 23:56] Guard #1117 begins shift
#
# {'month': 10, 'day': 25, 'offset': -4, 'action': '#1117'}
# Changing guard to #1117
# [1518-10-25 00:17] falls asleep
#
# {'month': 10, 'day': 25, 'offset': 17, 'action': 'sleep'}
# Starting sleep at minute 17
# [1518-10-25 00:58] wakes up
#
# {'month': 10, 'day': 25, 'offset': 58, 'action': 'wake'}
# Updating counter between 17 and 58
# [1518-10-25 23:59] Guard #1051 begins shift
#
# {'month': 10, 'day': 26, 'offset': -1, 'action': '#1051'}
# Changing guard to #1051
# [1518-10-26 00:07] falls asleep
#
# {'month': 10, 'day': 26, 'offset': 7, 'action': 'sleep'}
# Starting sleep at minute 7
# [1518-10-26 00:46] wakes up
#
# {'month': 10, 'day': 26, 'offset': 46, 'action': 'wake'}
# Updating counter between 7 and 46
# [1518-10-26 23:51] Guard #353 begins shift
#
# {'month': 10, 'day': 27, 'offset': -9, 'action': '#353'}
# Changing guard to #353
# [1518-10-27 00:05] falls asleep
#
# {'month': 10, 'day': 27, 'offset': 5, 'action': 'sleep'}
# Starting sleep at minute 5
# [1518-10-27 00:12] wakes up
#
# {'month': 10, 'day': 27, 'offset': 12, 'action': 'wake'}
# Updating counter between 5 and 12
# [1518-10-27 00:33] falls asleep
#
# {'month': 10, 'day': 27, 'offset': 33, 'action': 'sleep'}
# Starting sleep at minute 33
# [1518-10-27 00:36] wakes up
#
# {'month': 10, 'day': 27, 'offset': 36, 'action': 'wake'}
# Updating counter between 33 and 36
# [1518-10-28 00:01] Guard #2399 begins shift
#
# {'month': 10, 'day': 28, 'offset': 1, 'action': '#2399'}
# Changing guard to #2399
# [1518-10-28 00:39] falls asleep
#
# {'month': 10, 'day': 28, 'offset': 39, 'action': 'sleep'}
# Starting sleep at minute 39
# [1518-10-28 00:50] wakes up
#
# {'month': 10, 'day': 28, 'offset': 50, 'action': 'wake'}
# Updating counter between 39 and 50
# [1518-10-28 23:58] Guard #1307 begins shift
#
# {'month': 10, 'day': 29, 'offset': -2, 'action': '#1307'}
# Changing guard to #1307
# [1518-10-29 00:34] falls asleep
#
# {'month': 10, 'day': 29, 'offset': 34, 'action': 'sleep'}
# Starting sleep at minute 34
# [1518-10-29 00:46] wakes up
#
# {'month': 10, 'day': 29, 'offset': 46, 'action': 'wake'}
# Updating counter between 34 and 46
# [1518-10-29 00:53] falls asleep
#
# {'month': 10, 'day': 29, 'offset': 53, 'action': 'sleep'}
# Starting sleep at minute 53
# [1518-10-29 00:58] wakes up
#
# {'month': 10, 'day': 29, 'offset': 58, 'action': 'wake'}
# Updating counter between 53 and 58
# [1518-10-30 00:00] Guard #3203 begins shift
#
# {'month': 10, 'day': 30, 'offset': 0, 'action': '#3203'}
# Changing guard to #3203
# [1518-10-30 00:40] falls asleep
#
# {'month': 10, 'day': 30, 'offset': 40, 'action': 'sleep'}
# Starting sleep at minute 40
# [1518-10-30 00:59] wakes up
#
# {'month': 10, 'day': 30, 'offset': 59, 'action': 'wake'}
# Updating counter between 40 and 59
# [1518-10-31 00:00] Guard #2267 begins shift
#
# {'month': 10, 'day': 31, 'offset': 0, 'action': '#2267'}
# Changing guard to #2267
# [1518-10-31 00:33] falls asleep
#
# {'month': 10, 'day': 31, 'offset': 33, 'action': 'sleep'}
# Starting sleep at minute 33
# [1518-10-31 00:52] wakes up
#
# {'month': 10, 'day': 31, 'offset': 52, 'action': 'wake'}
# Updating counter between 33 and 52
# [1518-11-01 00:02] Guard #1051 begins shift
#
# {'month': 11, 'day': 1, 'offset': 2, 'action': '#1051'}
# Changing guard to #1051
# [1518-11-01 00:14] falls asleep
#
# {'month': 11, 'day': 1, 'offset': 14, 'action': 'sleep'}
# Starting sleep at minute 14
# [1518-11-01 00:43] wakes up
#
# {'month': 11, 'day': 1, 'offset': 43, 'action': 'wake'}
# Updating counter between 14 and 43
# [1518-11-02 00:00] Guard #163 begins shift
#
# {'month': 11, 'day': 2, 'offset': 0, 'action': '#163'}
# Changing guard to #163
# [1518-11-02 00:29] falls asleep
#
# {'month': 11, 'day': 2, 'offset': 29, 'action': 'sleep'}
# Starting sleep at minute 29
# [1518-11-02 00:53] wakes up
#
# {'month': 11, 'day': 2, 'offset': 53, 'action': 'wake'}
# Updating counter between 29 and 53
# [1518-11-02 23:54] Guard #509 begins shift
#
# {'month': 11, 'day': 3, 'offset': -6, 'action': '#509'}
# Changing guard to #509
# [1518-11-03 00:02] falls asleep
#
# {'month': 11, 'day': 3, 'offset': 2, 'action': 'sleep'}
# Starting sleep at minute 2
# [1518-11-03 00:52] wakes up
#
# {'month': 11, 'day': 3, 'offset': 52, 'action': 'wake'}
# Updating counter between 2 and 52
# [1518-11-04 00:01] Guard #2851 begins shift
#
# {'month': 11, 'day': 4, 'offset': 1, 'action': '#2851'}
# Changing guard to #2851
# [1518-11-04 00:10] falls asleep
#
# {'month': 11, 'day': 4, 'offset': 10, 'action': 'sleep'}
# Starting sleep at minute 10
# [1518-11-04 00:30] wakes up
#
# {'month': 11, 'day': 4, 'offset': 30, 'action': 'wake'}
# Updating counter between 10 and 30
# [1518-11-04 00:33] falls asleep
#
# {'month': 11, 'day': 4, 'offset': 33, 'action': 'sleep'}
# Starting sleep at minute 33
# [1518-11-04 00:57] wakes up
#
# {'month': 11, 'day': 4, 'offset': 57, 'action': 'wake'}
# Updating counter between 33 and 57
# [1518-11-04 23:46] Guard #2851 begins shift
#
# {'month': 11, 'day': 5, 'offset': -14, 'action': '#2851'}
# Changing guard to #2851
# [1518-11-05 00:01] falls asleep
#
# {'month': 11, 'day': 5, 'offset': 1, 'action': 'sleep'}
# Starting sleep at minute 1
# [1518-11-05 00:22] wakes up
#
# {'month': 11, 'day': 5, 'offset': 22, 'action': 'wake'}
# Updating counter between 1 and 22
# [1518-11-05 00:28] falls asleep
#
# {'month': 11, 'day': 5, 'offset': 28, 'action': 'sleep'}
# Starting sleep at minute 28
# [1518-11-05 00:43] wakes up
#
# {'month': 11, 'day': 5, 'offset': 43, 'action': 'wake'}
# Updating counter between 28 and 43
# [1518-11-05 00:50] falls asleep
#
# {'month': 11, 'day': 5, 'offset': 50, 'action': 'sleep'}
# Starting sleep at minute 50
# [1518-11-05 00:59] wakes up
#
# {'month': 11, 'day': 5, 'offset': 59, 'action': 'wake'}
# Updating counter between 50 and 59
# [1518-11-06 00:02] Guard #3559 begins shift
#
# {'month': 11, 'day': 6, 'offset': 2, 'action': '#3559'}
# Changing guard to #3559
# [1518-11-06 00:22] falls asleep
#
# {'month': 11, 'day': 6, 'offset': 22, 'action': 'sleep'}
# Starting sleep at minute 22
# [1518-11-06 00:40] wakes up
#
# {'month': 11, 'day': 6, 'offset': 40, 'action': 'wake'}
# Updating counter between 22 and 40
# [1518-11-06 00:45] falls asleep
#
# {'month': 11, 'day': 6, 'offset': 45, 'action': 'sleep'}
# Starting sleep at minute 45
# [1518-11-06 00:59] wakes up
#
# {'month': 11, 'day': 6, 'offset': 59, 'action': 'wake'}
# Updating counter between 45 and 59
# [1518-11-06 23:58] Guard #1117 begins shift
#
# {'month': 11, 'day': 7, 'offset': -2, 'action': '#1117'}
# Changing guard to #1117
# [1518-11-07 00:29] falls asleep
#
# {'month': 11, 'day': 7, 'offset': 29, 'action': 'sleep'}
# Starting sleep at minute 29
# [1518-11-07 00:47] wakes up
#
# {'month': 11, 'day': 7, 'offset': 47, 'action': 'wake'}
# Updating counter between 29 and 47
# [1518-11-07 23:50] Guard #2399 begins shift
#
# {'month': 11, 'day': 8, 'offset': -10, 'action': '#2399'}
# Changing guard to #2399
# [1518-11-08 00:05] falls asleep
#
# {'month': 11, 'day': 8, 'offset': 5, 'action': 'sleep'}
# Starting sleep at minute 5
# [1518-11-08 00:41] wakes up
#
# {'month': 11, 'day': 8, 'offset': 41, 'action': 'wake'}
# Updating counter between 5 and 41
# [1518-11-09 00:00] Guard #3203 begins shift
#
# {'month': 11, 'day': 9, 'offset': 0, 'action': '#3203'}
# Changing guard to #3203
# [1518-11-09 00:18] falls asleep
#
# {'month': 11, 'day': 9, 'offset': 18, 'action': 'sleep'}
# Starting sleep at minute 18
# [1518-11-09 00:56] wakes up
#
# {'month': 11, 'day': 9, 'offset': 56, 'action': 'wake'}
# Updating counter between 18 and 56
# [1518-11-09 23:59] Guard #3559 begins shift
#
# {'month': 11, 'day': 10, 'offset': -1, 'action': '#3559'}
# Changing guard to #3559
# [1518-11-10 00:56] falls asleep
#
# {'month': 11, 'day': 10, 'offset': 56, 'action': 'sleep'}
# Starting sleep at minute 56
# [1518-11-10 00:58] wakes up
#
# {'month': 11, 'day': 10, 'offset': 58, 'action': 'wake'}
# Updating counter between 56 and 58
# [1518-11-10 23:59] Guard #1091 begins shift
#
# {'month': 11, 'day': 11, 'offset': -1, 'action': '#1091'}
# Changing guard to #1091
# [1518-11-11 00:39] falls asleep
#
# {'month': 11, 'day': 11, 'offset': 39, 'action': 'sleep'}
# Starting sleep at minute 39
# [1518-11-11 00:42] wakes up
#
# {'month': 11, 'day': 11, 'offset': 42, 'action': 'wake'}
# Updating counter between 39 and 42
# [1518-11-12 00:03] Guard #353 begins shift
#
# {'month': 11, 'day': 12, 'offset': 3, 'action': '#353'}
# Changing guard to #353
# [1518-11-12 00:10] falls asleep
#
# {'month': 11, 'day': 12, 'offset': 10, 'action': 'sleep'}
# Starting sleep at minute 10
# [1518-11-12 00:56] wakes up
#
# {'month': 11, 'day': 12, 'offset': 56, 'action': 'wake'}
# Updating counter between 10 and 56
# [1518-11-13 00:00] Guard #509 begins shift
#
# {'month': 11, 'day': 13, 'offset': 0, 'action': '#509'}
# Changing guard to #509
# [1518-11-13 00:22] falls asleep
#
# {'month': 11, 'day': 13, 'offset': 22, 'action': 'sleep'}
# Starting sleep at minute 22
# [1518-11-13 00:25] wakes up
#
# {'month': 11, 'day': 13, 'offset': 25, 'action': 'wake'}
# Updating counter between 22 and 25
# [1518-11-13 00:33] falls asleep
#
# {'month': 11, 'day': 13, 'offset': 33, 'action': 'sleep'}
# Starting sleep at minute 33
# [1518-11-13 00:56] wakes up
#
# {'month': 11, 'day': 13, 'offset': 56, 'action': 'wake'}
# Updating counter between 33 and 56
# [1518-11-13 23:58] Guard #2851 begins shift
#
# {'month': 11, 'day': 14, 'offset': -2, 'action': '#2851'}
# Changing guard to #2851
# [1518-11-14 00:08] falls asleep
#
# {'month': 11, 'day': 14, 'offset': 8, 'action': 'sleep'}
# Starting sleep at minute 8
# [1518-11-14 00:16] wakes up
#
# {'month': 11, 'day': 14, 'offset': 16, 'action': 'wake'}
# Updating counter between 8 and 16
# [1518-11-14 00:20] falls asleep
#
# {'month': 11, 'day': 14, 'offset': 20, 'action': 'sleep'}
# Starting sleep at minute 20
# [1518-11-14 00:50] wakes up
#
# {'month': 11, 'day': 14, 'offset': 50, 'action': 'wake'}
# Updating counter between 20 and 50
# [1518-11-14 23:58] Guard #1601 begins shift
#
# {'month': 11, 'day': 15, 'offset': -2, 'action': '#1601'}
# Changing guard to #1601
# [1518-11-15 00:24] falls asleep
#
# {'month': 11, 'day': 15, 'offset': 24, 'action': 'sleep'}
# Starting sleep at minute 24
# [1518-11-15 00:59] wakes up
#
# {'month': 11, 'day': 15, 'offset': 59, 'action': 'wake'}
# Updating counter between 24 and 59
# [1518-11-15 23:59] Guard #691 begins shift
#
# {'month': 11, 'day': 16, 'offset': -1, 'action': '#691'}
# Changing guard to #691
# [1518-11-16 00:31] falls asleep
#
# {'month': 11, 'day': 16, 'offset': 31, 'action': 'sleep'}
# Starting sleep at minute 31
# [1518-11-16 00:53] wakes up
#
# {'month': 11, 'day': 16, 'offset': 53, 'action': 'wake'}
# Updating counter between 31 and 53
# [1518-11-17 00:01] Guard #163 begins shift
#
# {'month': 11, 'day': 17, 'offset': 1, 'action': '#163'}
# Changing guard to #163
# [1518-11-17 00:20] falls asleep
#
# {'month': 11, 'day': 17, 'offset': 20, 'action': 'sleep'}
# Starting sleep at minute 20
# [1518-11-17 00:24] wakes up
#
# {'month': 11, 'day': 17, 'offset': 24, 'action': 'wake'}
# Updating counter between 20 and 24
# [1518-11-17 00:29] falls asleep
#
# {'month': 11, 'day': 17, 'offset': 29, 'action': 'sleep'}
# Starting sleep at minute 29
# [1518-11-17 00:39] wakes up
#
# {'month': 11, 'day': 17, 'offset': 39, 'action': 'wake'}
# Updating counter between 29 and 39
# [1518-11-17 00:44] falls asleep
#
# {'month': 11, 'day': 17, 'offset': 44, 'action': 'sleep'}
# Starting sleep at minute 44
# [1518-11-17 00:52] wakes up
#
# {'month': 11, 'day': 17, 'offset': 52, 'action': 'wake'}
# Updating counter between 44 and 52
# [1518-11-17 23:59] Guard #1051 begins shift
#
# {'month': 11, 'day': 18, 'offset': -1, 'action': '#1051'}
# Changing guard to #1051
# [1518-11-18 00:17] falls asleep
#
# {'month': 11, 'day': 18, 'offset': 17, 'action': 'sleep'}
# Starting sleep at minute 17
# [1518-11-18 00:31] wakes up
#
# {'month': 11, 'day': 18, 'offset': 31, 'action': 'wake'}
# Updating counter between 17 and 31
# [1518-11-18 00:39] falls asleep
#
# {'month': 11, 'day': 18, 'offset': 39, 'action': 'sleep'}
# Starting sleep at minute 39
# [1518-11-18 00:40] wakes up
#
# {'month': 11, 'day': 18, 'offset': 40, 'action': 'wake'}
# Updating counter between 39 and 40
# [1518-11-19 00:00] Guard #2399 begins shift
#
# {'month': 11, 'day': 19, 'offset': 0, 'action': '#2399'}
# Changing guard to #2399
# [1518-11-19 00:14] falls asleep
#
# {'month': 11, 'day': 19, 'offset': 14, 'action': 'sleep'}
# Starting sleep at minute 14
# [1518-11-19 00:22] wakes up
#
# {'month': 11, 'day': 19, 'offset': 22, 'action': 'wake'}
# Updating counter between 14 and 22
# [1518-11-19 00:43] falls asleep
#
# {'month': 11, 'day': 19, 'offset': 43, 'action': 'sleep'}
# Starting sleep at minute 43
# [1518-11-19 00:51] wakes up
#
# {'month': 11, 'day': 19, 'offset': 51, 'action': 'wake'}
# Updating counter between 43 and 51
# [1518-11-19 23:59] Guard #691 begins shift
#
# {'month': 11, 'day': 20, 'offset': -1, 'action': '#691'}
# Changing guard to #691
# [1518-11-20 00:34] falls asleep
#
# {'month': 11, 'day': 20, 'offset': 34, 'action': 'sleep'}
# Starting sleep at minute 34
# [1518-11-20 00:39] wakes up
#
# {'month': 11, 'day': 20, 'offset': 39, 'action': 'wake'}
# Updating counter between 34 and 39
# [1518-11-20 00:46] falls asleep
#
# {'month': 11, 'day': 20, 'offset': 46, 'action': 'sleep'}
# Starting sleep at minute 46
# [1518-11-20 00:58] wakes up
#
# {'month': 11, 'day': 20, 'offset': 58, 'action': 'wake'}
# Updating counter between 46 and 58
# [1518-11-20 23:59] Guard #2617 begins shift
#
# {'month': 11, 'day': 21, 'offset': -1, 'action': '#2617'}
# Changing guard to #2617
# [1518-11-21 00:38] falls asleep
#
# {'month': 11, 'day': 21, 'offset': 38, 'action': 'sleep'}
# Starting sleep at minute 38
# [1518-11-21 00:44] wakes up
#
# {'month': 11, 'day': 21, 'offset': 44, 'action': 'wake'}
# Updating counter between 38 and 44
# [1518-11-21 23:58] Guard #509 begins shift
#
# {'month': 11, 'day': 22, 'offset': -2, 'action': '#509'}
# Changing guard to #509
# [1518-11-22 00:14] falls asleep
#
# {'month': 11, 'day': 22, 'offset': 14, 'action': 'sleep'}
# Starting sleep at minute 14
# [1518-11-22 00:27] wakes up
#
# {'month': 11, 'day': 22, 'offset': 27, 'action': 'wake'}
# Updating counter between 14 and 27
# [1518-11-22 00:43] falls asleep
#
# {'month': 11, 'day': 22, 'offset': 43, 'action': 'sleep'}
# Starting sleep at minute 43
# [1518-11-22 00:44] wakes up
#
# {'month': 11, 'day': 22, 'offset': 44, 'action': 'wake'}
# Updating counter between 43 and 44
# [1518-11-23 00:04] Guard #3559 begins shift
#
# {'month': 11, 'day': 23, 'offset': 4, 'action': '#3559'}
# Changing guard to #3559
# [1518-11-23 00:31] falls asleep
#
# {'month': 11, 'day': 23, 'offset': 31, 'action': 'sleep'}
# Starting sleep at minute 31
# [1518-11-23 00:37] wakes up
#
# {'month': 11, 'day': 23, 'offset': 37, 'action': 'wake'}
# Updating counter between 31 and 37
# [1518-11-23 00:41] falls asleep
#
# {'month': 11, 'day': 23, 'offset': 41, 'action': 'sleep'}
# Starting sleep at minute 41
# [1518-11-23 00:50] wakes up
#
# {'month': 11, 'day': 23, 'offset': 50, 'action': 'wake'}
# Updating counter between 41 and 50

# %%
guardSums = [(guard, sum(d.values())) for guard, d in sleepCounter.items()]
sortedGuards = sorted(guardSums, key=lambda x: x[1], reverse=True)
print(sortedGuards)
maxGuard, minsAsleep = sortedGuards[0]
print(maxGuard, minsAsleep)
guardMinutes = sleepCounter[maxGuard]
sortedGuardsMins = sorted([(m, v) for m, v in guardMinutes.items()], key=lambda x: x[1], reverse=True)
print(sortedGuardsMins)
maxMinute, numOccurrences = sortedGuardsMins[0]
print(maxMinute, numOccurrences)
print(int(maxGuard[1:]))
print(maxMinute)
result = int(maxGuard[1:]) * maxMinute
result
# Out:
# [('#1601', 483), ('#2267', 476), ('#2399', 468), ('#163', 447), ('#2851', 412), ('#1307', 362), ('#353', 353), ('#1051', 343), ('#2153', 343), ('#3203', 315), ('#2447', 302), ('#691', 265), ('#509', 246), ('#1091', 246), ('#269', 224), ('#3559', 206), ('#2333', 195), ('#349', 188), ('#2617', 161), ('#1117', 144)]
# #1601 483
# [(46, 14), (45, 13), (47, 13), (41, 12), (42, 12), (43, 12), (44, 12), (48, 12), (34, 11), (37, 11), (38, 11), (40, 11), (49, 11), (50, 11), (26, 10), (27, 10), (35, 10), (36, 10), (39, 10), (51, 10), (52, 10), (53, 9), (54, 9), (20, 9), (24, 9), (25, 9), (28, 9), (29, 9), (30, 9), (31, 9), (32, 9), (33, 9), (55, 8), (56, 8), (21, 8), (23, 8), (14, 7), (15, 7), (22, 7), (19, 7), (6, 6), (7, 6), (8, 6), (9, 6), (10, 6), (13, 6), (16, 6), (17, 6), (18, 6), (11, 5), (12, 5), (3, 4), (4, 4), (5, 4), (57, 3), (58, 3), (2, 3), (1, 2), (0, 1)]
# 46 14
# 1601
# 46
# 73646

# %%
def getMaxMin(guard):
    guardMinutes = sleepCounter[guard]
    sortedGuardsMins = sorted([(m, v) for m, v in guardMinutes.items()], key=lambda x: x[1], reverse=True)
#    print(sortedGuardsMins)
    return sortedGuardsMins[0]

# %%
guardMins = [(guard, getMaxMin(guard)) for guard in sleepCounter]
sortedGuardMins = sorted(guardMins, key=lambda x: x[1][1], reverse=True)
print(sortedGuardMins)
guard, maxMinAndVal = sortedGuardMins[0]
print(guard[1:], maxMinAndVal[0])
result = int(guard[1:]) * maxMinAndVal[0]
result
# Out:
# [('#163', (29, 18)), ('#2267', (36, 15)), ('#1601', (46, 14)), ('#2399', (21, 13)), ('#1051', (30, 12)), ('#1307', (41, 11)), ('#2851', (28, 11)), ('#353', (31, 10)), ('#691', (48, 9)), ('#2153', (34, 9)), ('#2447', (17, 9)), ('#3203', (40, 9)), ('#3559', (45, 9)), ('#1091', (39, 8)), ('#509', (17, 7)), ('#2617', (46, 7)), ('#349', (35, 6)), ('#1117', (45, 6)), ('#269', (45, 6)), ('#2333', (16, 5))]
# 163 29
# 4727
